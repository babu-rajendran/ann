# %% [markdown]
# Using any data set you want, implement colabs for the following ANN algorithms (see hints)
#
# Write proper documentation in read.me file and colabs
#
# a) LSH
#
# b) exhaustive search
#
# c) product quantization
#
# d) trees and graphs
#
# e) hnsw

# %% [markdown]
# I am using the Netflix titles dataset available at https://www.kaggle.com/shivamb/netflix-shows

# %% [markdown]
# Load the Google Drive to access the dataset

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# Install the required libraries

# %%
# !python -m pip install --upgrade faiss faiss-gpu
# !pip install datasketch
# !pip install sentence_transformers
# !pip install hnswlib
# !pip install nmslib
# !pip install annoy
# Out:
# Requirement already satisfied: faiss in /usr/local/lib/python3.7/dist-packages (1.5.3)
# Requirement already satisfied: faiss-gpu in /usr/local/lib/python3.7/dist-packages (1.7.1.post3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from faiss) (1.19.5)
# Requirement already satisfied: datasketch in /usr/local/lib/python3.7/dist-packages (1.5.4)
# Requirement already satisfied: numpy>=1.11 in /usr/local/lib/python3.7/dist-packages (from datasketch) (1.19.5)
# Requirement already satisfied: sentence_transformers in /usr/local/lib/python3.7/dist-packages (2.1.0)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /usr/local/lib/python3.7/dist-packages (from sentence_transformers) (4.12.5)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from sentence_transformers) (0.11.1+cu111)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from sentence_transformers) (3.2.5)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.7/dist-packages (from sentence_transformers) (0.1.96)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.7/dist-packages (from sentence_transformers) (0.2.1)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from sentence_transformers) (1.10.0+cu111)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from sentence_transformers) (1.19.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from sentence_transformers) (4.62.3)
# Requirement already satisfied: tokenizers>=0.10.3 in /usr/local/lib/python3.7/dist-packages (from sentence_transformers) (0.10.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from sentence_transformers) (1.0.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from sentence_transformers) (1.4.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.6.0->sentence_transformers) (3.10.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (21.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (2019.12.20)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (3.4.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (2.23.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (6.0)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (0.0.46)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (4.8.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers<5.0.0,>=4.6.0->sentence_transformers) (3.0.6)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers<5.0.0,>=4.6.0->sentence_transformers) (3.6.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nltk->sentence_transformers) (1.15.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence_transformers) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence_transformers) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence_transformers) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence_transformers) (3.0.4)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers<5.0.0,>=4.6.0->sentence_transformers) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers<5.0.0,>=4.6.0->sentence_transformers) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sentence_transformers) (3.0.0)
# Requirement already satisfied: pillow!=8.3.0,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision->sentence_transformers) (7.1.2)
# Requirement already satisfied: hnswlib in /usr/local/lib/python3.7/dist-packages (0.5.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from hnswlib) (1.19.5)
# Requirement already satisfied: nmslib in /usr/local/lib/python3.7/dist-packages (2.1.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.7/dist-packages (from nmslib) (5.4.8)
# Requirement already satisfied: pybind11<2.6.2 in /usr/local/lib/python3.7/dist-packages (from nmslib) (2.6.1)
# Requirement already satisfied: numpy>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from nmslib) (1.19.5)
# Requirement already satisfied: annoy in /usr/local/lib/python3.7/dist-packages (1.17.0)

# %% [markdown]
# Import the dependencies

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sn
import math
import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')
from sklearn.feature_extraction.text import TfidfVectorizer
from sentence_transformers import SentenceTransformer, util
import nmslib
import hnswlib

# %% [markdown]
# Load the dataset and check the shape

# %%
df = pd.read_csv('/content/gdrive/MyDrive/msse/fall-21/data-mining/netflix_titles.csv')
df.shape
# Out:
# (8807, 12)

# %%
df.head(10)
# Out:
#   show_id  ...                                        description
# 0      s1  ...  As her father nears the end of his life, filmm...
# 1      s2  ...  After crossing paths at a party, a Cape Town t...
# 2      s3  ...  To protect his family from a powerful drug lor...
# 3      s4  ...  Feuds, flirtations and toilet talk go down amo...
# 4      s5  ...  In a city of coaching centers known to train I...
# 5      s6  ...  The arrival of a charismatic young priest brin...
# 6      s7  ...  Equestria's divided. But a bright-eyed hero be...
# 7      s8  ...  On a photo shoot in Ghana, an American model s...
# 8      s9  ...  A talented batch of amateur bakers face off in...
# 9     s10  ...  A woman adjusting to life after a loss contend...
#
# [10 rows x 12 columns]

# %%
df.drop(columns=["country", "date_added", "type", "rating", "duration", "cast", "show_id"], inplace= True)
df["text"] = df["title"] + " " + df["description"]
df.head(10)
# Out:
#                               title  ...                                               text
# 0              Dick Johnson Is Dead  ...  Dick Johnson Is Dead As her father nears the e...
# 1                     Blood & Water  ...  Blood & Water After crossing paths at a party,...
# 2                         Ganglands  ...  Ganglands To protect his family from a powerfu...
# 3             Jailbirds New Orleans  ...  Jailbirds New Orleans Feuds, flirtations and t...
# 4                      Kota Factory  ...  Kota Factory In a city of coaching centers kno...
# 5                     Midnight Mass  ...  Midnight Mass The arrival of a charismatic you...
# 6  My Little Pony: A New Generation  ...  My Little Pony: A New Generation Equestria's d...
# 7                           Sankofa  ...  Sankofa On a photo shoot in Ghana, an American...
# 8     The Great British Baking Show  ...  The Great British Baking Show A talented batch...
# 9                      The Starling  ...  The Starling A woman adjusting to life after a...
#
# [10 rows x 6 columns]

# %% [markdown]
# To effeciently run on colab, just use the first 1000 records. As using more data to process caused the colab to crash as it is using high-RAM.

# %%
df = df[0:1000]
df.shape
# Out:
# (1000, 6)

# %% [markdown]
# **Locality Sensitive Hashing**

# %%
import re
import time
from datasketch import MinHash, MinHashLSHForest

# %% [markdown]
# Create a function to preprocess the data:

# %%
def preprocess(text):
    text = re.sub(r'[^\w\s]','',text)
    tokens = text.lower()
    tokens = tokens.split()
    return tokens

# %%
# Function to get the forest

def get_forest(data, perms):
    start_time = time.time()
    
    minhash = []
    
    for text in data['text']:
        tokens = preprocess(text)
        m = MinHash(num_perm=perms)
        for s in tokens:
            m.update(s.encode('utf8'))
        minhash.append(m)
        
    forest = MinHashLSHForest(num_perm=perms)
    
    for i,m in enumerate(minhash):
        forest.add(i,m)
        
    forest.index()
    
    print('It took %s seconds to build forest.' %(time.time()-start_time))
    
    return forest

# %%
# Function for recommending results based on similar query terms
def predict(text, database, perms, num_results, forest):
    start_time = time.time()
    
    tokens = preprocess(text)
    m = MinHash(num_perm=perms)
    for s in tokens:
        m.update(s.encode('utf8'))
        
    idx_array = np.array(forest.query(m, num_results))
    if len(idx_array) == 0:
        return None # if your query is empty, return none
    
    result = database.iloc[idx_array]['title']
    
    print('It took %s seconds to query forest.' %(time.time()-start_time))
    
    return result

# %%
permutations = 128

num_recommendations = 1

# %% [markdown]
# Create the forest and search it based on a search query and get the recommended titles.

# %%
forest = get_forest(df, permutations)
# Out:
# It took 1.8603973388671875 seconds to build forest.

# %%
num_recommendations = 5
title = 'Love'
result = predict(title, df, permutations, num_recommendations, forest)
print('\n Top Recommendation(s) is(are) \n', result)
# Out:
# It took 0.007761955261230469 seconds to query forest.
#
#  Top Recommendation(s) is(are)
#  544            Workin' Moms
# 438        2 Weeks in Lagos
# 247              Sweet Girl
# 569             Dreamy Eyes
# 25     Love on the Spectrum
# Name: title, dtype: object

# %% [markdown]
# **Exhaustive Search**

# %%
# !pip install faiss-cpu
# Out:
# Requirement already satisfied: faiss-cpu in /usr/local/lib/python3.7/dist-packages (1.7.1.post3)

# %%
import faiss

# %%
df['Index'] = df.index
tfidf = TfidfVectorizer(analyzer='word',ngram_range=(1, 3),min_df=0,stop_words='english')
X_tfidf = tfidf.fit_transform(df['text'])
X_tfidf
# Out:
# <1000x34545 sparse matrix of type '<class 'numpy.float64'>'
# 	with 44837 stored elements in Compressed Sparse Row format>

# %%
vector = X_tfidf.toarray()
vector[0].shape[0]
# Out:
# 34545

# %%
class ExactIndex():
    def __init__(self, vectors, labels):
        self.dimension = vectors.shape[1]
        self.vectors = vectors.astype('float32')
        self.labels = labels    
   
    def build(self):
        self.index = faiss.IndexFlatL2(self.dimension,)
        self.index.add(self.vectors)
        
    def query(self, vectors, k=10):
        distances, indices = self.index.search(vectors, k) 
        # I expect only query on one vector thus the slice
        return [self.labels[i] for i in indices[0]]

# %%
# %%time
index = ExactIndex(vector, df["Index"])
index.build()
# Out:
# CPU times: user 85.8 ms, sys: 165 ms, total: 250 ms
# Wall time: 257 ms

# %%
query_index = 5
print(f"The most similar items to item {df['Index'][query_index]} are:")

items_list = index.query(np.array([vector[query_index]]).astype('float32'))
df.loc[df['Index'].isin(items_list)]
# Out:
# The most similar items to item 5 are:
#                                     title  ... Index
# 5                           Midnight Mass  ...     5
# 86                                   Prey  ...    86
# 307                             Aftermath  ...   307
# 412  Chhota Bheem and the Incan Adventure  ...   412
# 643                       The Seventh Day  ...   643
# 745                        Until Midnight  ...   745
# 782                                 Bliss  ...   782
# 866                      Small Town Crime  ...   866
# 918                        Lava Ka Dhaava  ...   918
# 932                            Green Zone  ...   932
#
# [10 rows x 7 columns]

# %% [markdown]
# **Product Quantization**

# %%
model = SentenceTransformer('paraphrase-distilroberta-base-v1')
# Out:
# Downloading:   0%|          | 0.00/391 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/3.74k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/718 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/122 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/229 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/329M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.35k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/798k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
# %%time
embeddings = model.encode(df['text'].tolist())
faiss.normalize_L2(embeddings)
# Out:
# CPU times: user 1min 11s, sys: 912 ms, total: 1min 12s
# Wall time: 1min 11s

# %%
print("Shape of the Embeddings:",embeddings.shape)
# Out:
# Shape of the Embeddings: (1000, 768)

# %%
dim=768
ncentroids=50
quantiser = faiss.IndexFlatL2(dim)
index = faiss.IndexIVFPQ (quantiser, dim,ncentroids, 16 , 8)
index.train(embeddings) 
print(index.is_trained)
faiss.write_index(index, "trained.index")
# Out:
# True

# %%
ids = df['Index'].tolist()
ids = np.array(ids)
index.add_with_ids(embeddings,ids)
print(index.ntotal)
# Out:
# 1000

# %%
faiss.write_index(index,"block.index")

# %%
def searchFAISSIndex(data, id_col_name, query, index, nprobe, model, topk=20):
    query_embedding=model.encode([query])[0]
    dim=query_embedding.shape[0]
    query_embedding=query_embedding.reshape(1,dim)
    faiss.normalize_L2(query_embedding)
  
    index.nprobe=nprobe
    
    D,I=index.search(query_embedding,topk) 
    ids=[i for i in I][0]
    L2_score=[d for d in D][0]
    inner_product=[calculateInnerProduct(l2) for l2 in L2_score]
    search_result=pd.DataFrame()
    search_result[id_col_name]=ids
    search_result['cosine_sim']=inner_product
    search_result['L2_score']=L2_score
    dat=data[data[id_col_name].isin(ids)]
    dat=pd.merge(dat,search_result,on=id_col_name)
    dat=dat.sort_values('cosine_sim',ascending=False)
    return dat

# %%
def calculateInnerProduct(L2_score):
    return (2-math.pow(L2_score,2))/2

# %% [markdown]
# For a given query and it should give the top recommended titles matching the queries (in this case the top 20 and the cosine_sim and L2 scores.

# %%
query = "As her father nears the end of his life"
search_result = searchFAISSIndex(df, "Index", query, index, nprobe=10, model= model, topk=20)
search_result = search_result[['Index', 'title', 'description', 'cosine_sim', 'L2_score']]

# %%
search_result
# Out:
#     Index                   title  ... cosine_sim  L2_score
# 3     160               Major Dad  ...   0.566016  0.931648
# 0       0    Dick Johnson Is Dead  ...   0.555232  0.943152
# 6     438        2 Weeks in Lagos  ...   0.548050  0.950737
# 15    795           Happy Endings  ...   0.508905  0.991055
# 2      24                   Jeans  ...   0.499346  1.000654
# 9     498                   Clash  ...   0.493881  1.006101
# 16    871      Sardar Ka Grandson  ...   0.493855  1.006126
# 18    971          Between Worlds  ...   0.493037  1.006939
# 17    969    August: Osage County  ...   0.486912  1.013004
# 12    662               Champions  ...   0.480919  1.018902
# 7     469          American Woman  ...   0.477092  1.022651
# 4     163      My Boss's Daughter  ...   0.476563  1.023168
# 11    652    Osuofia in London II  ...   0.475231  1.024470
# 13    685              Fatherhood  ...   0.474163  1.025512
# 5     426                 Cousins  ...   0.465233  1.034183
# 14    704  A Man For The Week End  ...   0.462509  1.036814
# 1      22         Avvai Shanmughi  ...   0.461863  1.037436
# 19    976            Among Family  ...   0.461792  1.037504
# 8     489             Back to Q82  ...   0.456875  1.042233
# 10    544            Workin' Moms  ...   0.453023  1.045923
#
# [20 rows x 5 columns]

# %% [markdown]
# **Trees and Graphs**

# %%
import nltk
from nltk.corpus import wordnet as wn
import annoy

# %% [markdown]
# Use AnnoyIndex to create a graph and run it on the tokenized vector created earlier using Tfidf

# %%
class TreeGraphIndex():
    def __init__(self, vectors, labels):
        self.dimention = vectors[0].shape[0]
        self.vectors = vectors.astype('float32')
        self.labels = labels


    def build(self, number_of_trees=5):
        self.index = annoy.AnnoyIndex(self.dimention, metric='angular')
        for i, vec in enumerate(self.vectors):
            self.index.add_item(i, vec.tolist())
        self.index.build(number_of_trees)
        
    def query(self, vector, k=10):
        indices = self.index.get_nns_by_vector(vector.tolist(), k)
        return [self.labels[i] for i in indices]

# %%
# %%time
tg_index = TreeGraphIndex(vector, df['Index'])
tg_index.build()
# Out:
# CPU times: user 2.2 s, sys: 104 ms, total: 2.3 s
# Wall time: 2.32 s

# %% [markdown]
# Query using an index and the results should be displayed

# %%
query_index = 5
print(f"The most similar items to item {df['Index'][query_index]} are:")
items_list = tg_index.query(vector[query_index])
df.loc[df['Index'].isin(items_list)]
# Out:
# The most similar items to item 5 are:
#                                     title  ... Index
# 5                           Midnight Mass  ...     5
# 86                                   Prey  ...    86
# 307                             Aftermath  ...   307
# 412  Chhota Bheem and the Incan Adventure  ...   412
# 643                       The Seventh Day  ...   643
# 745                        Until Midnight  ...   745
# 782                                 Bliss  ...   782
# 866                      Small Town Crime  ...   866
# 918                        Lava Ka Dhaava  ...   918
# 932                            Green Zone  ...   932
#
# [10 rows x 7 columns]

# %% [markdown]
# **HSNW**

# %% [markdown]
# Create a new index using HSNW in Cosine similarity

# %%
index = nmslib.init(method='hnsw', space='cosinesimil')
index.addDataPointBatch(vector)
index.createIndex({'post': 2}, print_progress=True)

# %%
ids, distances = index.knnQuery(vector[0], k=10)

# %% [markdown]
# Look for the nearest neighbours of the first data point

# %%
neighbours = index.knnQueryBatch(vector, k=10, num_threads=4)

# %%
neighbours
# Out:
# [(array([  0,  76, 971, 415, 604, 704, 827, 854, 606, 823], dtype=int32),
#   array([3.5762787e-07, 9.6430832e-01, 9.6590835e-01, 9.7089767e-01,
#          9.7264051e-01, 9.7450113e-01, 9.7733998e-01, 9.7824931e-01,
#          9.7857738e-01, 9.7953868e-01], dtype=float32)),
#  (array([  1, 684, 613, 108, 146, 584, 943, 173, 113, 869], dtype=int32),
#   array([0.        , 0.95057994, 0.96222997, 0.969903  , 0.9718171 ,
#          0.97365874, 0.9746312 , 0.97484994, 0.97529346, 0.9761698 ],
#         dtype=float32)),
#  (array([  2, 318, 346, 424, 310, 791, 711, 212,  42, 150], dtype=int32),
#   array([0.        , 0.94609916, 0.9540503 , 0.95627904, 0.9584522 ,
#          0.95858157, 0.9621711 , 0.973085  , 0.9734023 , 0.97543454],
#         dtype=float32)),
#  (array([  3, 616, 526, 957, 466, 184,  74, 691, 647, 856], dtype=int32),
#   array([2.9802322e-07, 9.4733638e-01, 9.6415454e-01, 9.6443975e-01,
#          9.6794474e-01, 9.6795738e-01, 9.6934712e-01, 9.6974313e-01,
#          9.7006768e-01, 9.7683305e-01], dtype=float32)),
#  (array([  4, 968, 266,  87, 216, 805, 627, 948, 409, 749], dtype=int32),
#   array([1.1920929e-07, 9.6327895e-01, 9.6392804e-01, 9.7088867e-01,
#          9.7271931e-01, 9.7353899e-01, 9.7687101e-01, 9.7828323e-01,
#          9.7842211e-01, 9.7886431e-01], dtype=float32)),
#  (array([  5, 745, 866, 643, 918, 782, 307, 932, 412,  86], dtype=int32),
#   array([0.        , 0.961961  , 0.97215587, 0.9728318 , 0.9737415 ,
#          0.9753486 , 0.978341  , 0.9793594 , 0.97983044, 0.9815291 ],
#         dtype=float32)),
#  (array([  6, 525, 197, 555, 234, 188, 350, 104,  77, 779], dtype=int32),
#   array([0.        , 0.91982275, 0.96325153, 0.96801245, 0.9738206 ,
#          0.97395855, 0.9760013 , 0.9777515 , 0.9792576 , 0.9794491 ],
#         dtype=float32)),
#  (array([  7, 228, 981, 871, 392, 913, 209, 842, 863, 812], dtype=int32),
#   array([1.7881393e-07, 9.7784019e-01, 9.7821391e-01, 9.7901219e-01,
#          9.7932756e-01, 9.7941649e-01, 9.8257834e-01, 9.8289412e-01,
#          9.8315954e-01, 9.8723888e-01], dtype=float32)),
#  (array([  8, 928, 733, 704,  55, 641, 827, 751, 862, 144], dtype=int32),
#   array([0.        , 0.9467379 , 0.9671344 , 0.96780074, 0.96785086,
#          0.9756462 , 0.9763029 , 0.9779261 , 0.97908646, 0.9799556 ],
#         dtype=float32)),
#  (array([  9, 815, 306, 964, 665, 533, 398, 847, 905, 343], dtype=int32),
#   array([0.        , 0.96801966, 0.9703908 , 0.971     , 0.97499216,
#          0.97587776, 0.97595984, 0.97620064, 0.9763311 , 0.97769177],
#         dtype=float32)),
#  (array([ 10, 288, 166, 208, 953, 315, 754, 604, 707, 825], dtype=int32),
#   array([0.        , 0.9205914 , 0.9491973 , 0.9526502 , 0.95922863,
#          0.97238916, 0.9734684 , 0.9751718 , 0.97688246, 0.9770959 ],
#         dtype=float32)),
#  (array([ 11, 659, 636, 572, 657, 595, 980, 892, 191, 183], dtype=int32),
#   array([0.        , 0.916359  , 0.97440296, 0.9779674 , 0.97822994,
#          0.97876847, 0.97879255, 0.97927535, 0.98023736, 0.9802787 ],
#         dtype=float32)),
#  (array([ 12, 711, 122, 907, 991, 322, 669, 623, 964, 613], dtype=int32),
#   array([1.1920929e-07, 9.6077311e-01, 9.6743983e-01, 9.6784955e-01,
#          9.6792513e-01, 9.6924424e-01, 9.6954799e-01, 9.6963185e-01,
#          9.6986026e-01, 9.7039527e-01], dtype=float32)),
#  (array([ 13, 516, 606, 311, 517, 511, 815,  98, 584, 452], dtype=int32),
#   array([1.1920929e-07, 9.6055365e-01, 9.6760559e-01, 9.6995795e-01,
#          9.7205973e-01, 9.7289592e-01, 9.7352028e-01, 9.7425145e-01,
#          9.7587949e-01, 9.7691303e-01], dtype=float32)),
#  (array([ 14, 207, 351, 429, 749, 617, 166, 761, 490, 133], dtype=int32),
#   array([0.        , 0.9575877 , 0.9594567 , 0.9632332 , 0.9666782 ,
#          0.96689516, 0.96838015, 0.9695712 , 0.96967703, 0.9713687 ],
#         dtype=float32)),
#  (array([ 15, 627, 997, 138, 691, 533, 682, 474, 497, 139], dtype=int32),
#   array([0.        , 0.96071124, 0.96082056, 0.9655843 , 0.9738018 ,
#          0.97559977, 0.9767915 , 0.979482  , 0.9801551 , 0.9807992 ],
#         dtype=float32)),
#  (array([ 16,  19, 684, 109,  70, 715, 363, 886, 117, 320], dtype=int32),
#   array([0.        , 0.95770395, 0.9719488 , 0.97412056, 0.97449833,
#          0.9754211 , 0.97557414, 0.9792985 , 0.9814525 , 0.98236   ],
#         dtype=float32)),
#  (array([ 17, 502, 872, 784, 607, 962, 282, 541, 903, 318], dtype=int32),
#   array([0.        , 0.9333616 , 0.9466487 , 0.96652174, 0.9666187 ,
#          0.97135234, 0.97385967, 0.97738135, 0.9778205 , 0.97808665],
#         dtype=float32)),
#  (array([ 18, 962, 534, 307, 763, 190, 353, 427, 972, 783], dtype=int32),
#   array([0.        , 0.9457438 , 0.9470184 , 0.95718247, 0.9618244 ,
#          0.96773434, 0.969296  , 0.96947974, 0.97182226, 0.97211605],
#         dtype=float32)),
#  (array([ 19,  16, 259, 915, 132, 317, 867, 608, 283, 559], dtype=int32),
#   array([0.        , 0.95770395, 0.9758244 , 0.9765174 , 0.97691256,
#          0.9781062 , 0.9789074 , 0.9791922 , 0.98023677, 0.98055136],
#         dtype=float32)),
#  (array([ 20, 439, 315, 811, 308, 797, 320, 793, 843,  81], dtype=int32),
#   array([0.        , 0.9669267 , 0.96954936, 0.9733453 , 0.9740895 ,
#          0.98096836, 0.9810283 , 0.9815433 , 0.9828489 , 0.9829919 ],
#         dtype=float32)),
#  (array([ 21, 261, 644,  98, 367, 619, 610, 776, 435, 943], dtype=int32),
#   array([0.        , 0.9694314 , 0.9769069 , 0.97772664, 0.97882915,
#          0.97907   , 0.9794678 , 0.9796875 , 0.97973907, 0.9802031 ],
#         dtype=float32)),
#  (array([ 22, 489, 129, 753, 797, 859, 522, 976, 920, 900], dtype=int32),
#   array([0.        , 0.9608584 , 0.96892184, 0.97027224, 0.97905815,
#          0.979133  , 0.9794026 , 0.9797527 , 0.9812504 , 0.98199105],
#         dtype=float32)),
#  (array([ 23, 254, 872, 509,  34, 106, 530, 522, 232, 720], dtype=int32),
#   array([4.7683716e-07, 7.8151542e-01, 9.5914972e-01, 9.5943743e-01,
#          9.6332175e-01, 9.6629262e-01, 9.7029817e-01, 9.7074383e-01,
#          9.7156012e-01, 9.7738606e-01], dtype=float32)),
#  (array([ 24, 123, 180, 850, 742, 852, 851, 641, 649, 246], dtype=int32),
#   array([1.1920929e-07, 9.1574031e-01, 9.4300365e-01, 9.6626443e-01,
#          9.6644831e-01, 9.6743381e-01, 9.6750563e-01, 9.6857214e-01,
#          9.7423029e-01, 9.7653240e-01], dtype=float32)),
#  (array([ 25, 477, 397, 772, 480, 250, 402, 258, 675, 875], dtype=int32),
#   array([0.        , 0.89719695, 0.9354286 , 0.9361599 , 0.9629371 ,
#          0.9668699 , 0.9687007 , 0.9694334 , 0.97029686, 0.9707417 ],
#         dtype=float32)),
#  (array([ 26, 823, 692, 815, 203, 483, 438, 301, 285, 436], dtype=int32),
#   array([1.1920929e-07, 9.4497037e-01, 9.4519305e-01, 9.4699246e-01,
#          9.5062792e-01, 9.5289367e-01, 9.5677328e-01, 9.6072161e-01,
#          9.6215379e-01, 9.6782577e-01], dtype=float32)),
#  (array([ 27, 154, 295, 814, 818, 984, 830, 145, 805, 146], dtype=int32),
#   array([0.        , 0.93428534, 0.93865895, 0.94894093, 0.9541536 ,
#          0.95551914, 0.96657336, 0.97027695, 0.975783  , 0.97641206],
#         dtype=float32)),
#  (array([ 28, 506, 559, 779, 143, 719, 901, 856,  18, 882], dtype=int32),
#   array([0.        , 0.9615759 , 0.96722466, 0.9710633 , 0.9721747 ,
#          0.9736728 , 0.9752586 , 0.9757593 , 0.9772247 , 0.9778276 ],
#         dtype=float32)),
#  (array([ 29, 630, 163, 897, 393, 916, 485, 600, 466, 319], dtype=int32),
#   array([5.9604645e-08, 9.3927735e-01, 9.5172501e-01, 9.5610636e-01,
#          9.7252840e-01, 9.7331560e-01, 9.7737515e-01, 9.7840995e-01,
#          9.7842294e-01, 9.7848976e-01], dtype=float32)),
#  (array([ 30, 130, 533, 343, 220, 829, 701, 887, 186, 344], dtype=int32),
#   array([0.        , 0.9486519 , 0.95137906, 0.95503545, 0.9572368 ,
#          0.95942324, 0.9604016 , 0.96246123, 0.96877813, 0.9782151 ],
#         dtype=float32)),
#  (array([ 31, 425, 146, 982, 113, 680, 333, 655, 796, 144], dtype=int32),
#   array([1.1920929e-07, 8.8686508e-01, 9.5137918e-01, 9.5141411e-01,
#          9.5737660e-01, 9.6953452e-01, 9.7316867e-01, 9.7354954e-01,
#          9.7613722e-01, 9.7716784e-01], dtype=float32)),
#  (array([ 32, 782,  70, 505, 676, 217, 968, 648, 638, 170], dtype=int32),
#   array([0.        , 0.909105  , 0.95561945, 0.9570719 , 0.957251  ,
#          0.9621144 , 0.9653413 , 0.9653483 , 0.96594024, 0.9668304 ],
#         dtype=float32)),
#  (array([ 33, 834, 331,  75, 290, 232, 938, 600, 263, 560], dtype=int32),
#   array([1.1920929e-07, 9.4778258e-01, 9.5381457e-01, 9.5487392e-01,
#          9.7487563e-01, 9.7637463e-01, 9.7669411e-01, 9.7724611e-01,
#          9.7935700e-01, 9.8013079e-01], dtype=float32)),
#  (array([ 34, 104, 565, 940,  23, 780, 412, 861,  39,  77], dtype=int32),
#   array([1.1920929e-07, 8.4613687e-01, 9.6267843e-01, 9.6278340e-01,
#          9.6332175e-01, 9.6526664e-01, 9.7042924e-01, 9.7235405e-01,
#          9.7259116e-01, 9.7313714e-01], dtype=float32)),
#  (array([ 35, 108, 513, 935, 141, 863, 151, 451, 338, 904], dtype=int32),
#   array([0.        , 0.94883573, 0.9670701 , 0.9703959 , 0.9717098 ,
#          0.9732915 , 0.97349054, 0.97474444, 0.97644   , 0.9769299 ],
#         dtype=float32)),
#  (array([ 36, 216, 718, 467, 220, 330, 551, 318, 509, 130], dtype=int32),
#   array([0.        , 0.9577226 , 0.96201175, 0.9743747 , 0.9768036 ,
#          0.97749346, 0.97777885, 0.9794008 , 0.9800356 , 0.9808556 ],
#         dtype=float32)),
#  (array([ 37, 337, 733, 583, 701, 589, 216, 396, 201,  39], dtype=int32),
#   array([0.        , 0.9436344 , 0.9702482 , 0.9733482 , 0.9820941 ,
#          0.98244935, 0.9824728 , 0.9830232 , 0.9830951 , 0.9831077 ],
#         dtype=float32)),
#  (array([ 38, 423, 574, 573, 112, 295, 543,  80, 739, 625], dtype=int32),
#   array([1.1920929e-07, 9.0346932e-01, 9.0849680e-01, 9.1056085e-01,
#          9.1086632e-01, 9.5304906e-01, 9.5879704e-01, 9.6432084e-01,
#          9.6924716e-01, 9.7408158e-01], dtype=float32)),
#  (array([ 39, 418, 417, 104, 415, 412, 419, 406, 407, 420], dtype=int32),
#   array([1.1920929e-07, 9.2569000e-01, 9.2664289e-01, 9.2857742e-01,
#          9.3397093e-01, 9.3479604e-01, 9.3483961e-01, 9.4000089e-01,
#          9.4133109e-01, 9.4290942e-01], dtype=float32)),
#  (array([ 40, 400, 399, 386, 222, 370, 471, 752, 361, 719], dtype=int32),
#   array([0.        , 0.91201144, 0.91503716, 0.96443844, 0.9746723 ,
#          0.9773554 , 0.97749394, 0.9778194 , 0.9802246 , 0.98026174],
#         dtype=float32)),
#  (array([ 41,  44,  42,  43,  91, 338, 111, 279, 252, 351], dtype=int32),
#   array([0.        , 0.7707794 , 0.7980653 , 0.8619722 , 0.952011  ,
#          0.95356363, 0.96861887, 0.9708415 , 0.9747681 , 0.97533053],
#         dtype=float32)),
#  (array([ 42,  44,  41,  43,  91, 970, 667, 252, 922,   2], dtype=int32),
#   array([1.7881393e-07, 7.7191556e-01, 7.9806530e-01, 9.1190642e-01,
#          9.3540585e-01, 9.5049292e-01, 9.6973461e-01, 9.7284925e-01,
#          9.7339958e-01, 9.7340232e-01], dtype=float32)),
#  (array([ 43,  44,  41,  42, 299,  91, 513, 193, 160, 582], dtype=int32),
#   array([0.        , 0.8503002 , 0.8619722 , 0.9119064 , 0.97027147,
#          0.9727659 , 0.9747877 , 0.97525734, 0.9774005 , 0.9775602 ],
#         dtype=float32)),
#  (array([ 44,  41,  42,  43, 111, 901, 493, 252,  53, 810], dtype=int32),
#   array([0.        , 0.7707794 , 0.77191556, 0.8503002 , 0.9659652 ,
#          0.96607673, 0.9699076 , 0.97263443, 0.976225  , 0.97739   ],
#         dtype=float32)),
#  (array([ 45, 310, 130, 542, 458, 637, 350, 655, 426, 193], dtype=int32),
#   array([1.7881393e-07, 9.6921098e-01, 9.6924049e-01, 9.7445667e-01,
#          9.7652709e-01, 9.7909033e-01, 9.7997737e-01, 9.8025930e-01,
#          9.8123926e-01, 9.8142111e-01], dtype=float32)),
#  (array([ 46, 955, 607, 384, 472, 493, 272, 434, 228, 307], dtype=int32),
#   array([0.        , 0.9405166 , 0.9497983 , 0.9587806 , 0.9601409 ,
#          0.9667361 , 0.9720017 , 0.9722193 , 0.9731191 , 0.97349465],
#         dtype=float32)),
#  (array([ 47, 709, 293, 921, 273, 487, 875, 126, 900, 298], dtype=int32),
#   array([0.        , 0.9557021 , 0.96495265, 0.96800464, 0.97160226,
#          0.9743863 , 0.9752958 , 0.97710145, 0.9771792 , 0.9785631 ],
#         dtype=float32)),
#  (array([ 48, 150, 360, 582, 628, 333, 593, 215, 826, 686], dtype=int32),
#   array([1.7881393e-07, 9.4893050e-01, 9.6430421e-01, 9.6457690e-01,
#          9.6576643e-01, 9.6991587e-01, 9.7395301e-01, 9.7758758e-01,
#          9.7830510e-01, 9.7854376e-01], dtype=float32)),
#  (array([ 49, 806, 807, 731, 793, 534,  56,  51, 221, 681], dtype=int32),
#   array([0.        , 0.94235295, 0.94235295, 0.9521988 , 0.96342814,
#          0.9663556 , 0.9667894 , 0.96819824, 0.97312367, 0.97637314],
#         dtype=float32)),
#  (array([ 50, 786, 302, 610, 843, 754, 504, 936, 671, 929], dtype=int32),
#   array([0.        , 0.95839643, 0.9639193 , 0.96430135, 0.97755665,
#          0.97794527, 0.9787098 , 0.9789101 , 0.97924256, 0.9797978 ],
#         dtype=float32)),
#  (array([ 51,  53,  52,  54, 611, 602, 574,  49, 806, 807], dtype=int32),
#   array([0.        , 0.9189664 , 0.942178  , 0.9424403 , 0.9653974 ,
#          0.9660285 , 0.9666366 , 0.96819824, 0.9745512 , 0.9745512 ],
#         dtype=float32)),
#  (array([ 52,  54,  53,  51, 418,  94, 581, 829, 417,  59], dtype=int32),
#   array([1.1920929e-07, 9.0502596e-01, 9.3023455e-01, 9.4217801e-01,
#          9.6165466e-01, 9.7224629e-01, 9.7252721e-01, 9.7266221e-01,
#          9.7313422e-01, 9.7321558e-01], dtype=float32)),
#  (array([ 53,  54,  51,  52, 252, 506, 752, 763, 111, 951], dtype=int32),
#   array([1.1920929e-07, 9.1750526e-01, 9.1896641e-01, 9.3023455e-01,
#          9.5393711e-01, 9.6545255e-01, 9.6835721e-01, 9.6953058e-01,
#          9.6962261e-01, 9.7570086e-01], dtype=float32)),
#  (array([ 54,  52,  53, 627,  51,  59, 581, 416,  56, 662], dtype=int32),
#   array([0.        , 0.90502596, 0.91750526, 0.94187665, 0.9424403 ,
#          0.9574117 , 0.960191  , 0.967435  , 0.97086   , 0.9716382 ],
#         dtype=float32)),
#  (array([ 55, 431, 648,  83,  70, 865,   8, 641, 353, 268], dtype=int32),
#   array([2.9802322e-07, 9.4493473e-01, 9.5211661e-01, 9.5276248e-01,
#          9.5614421e-01, 9.6579009e-01, 9.6785086e-01, 9.6918720e-01,
#          9.7462153e-01, 9.7757632e-01], dtype=float32)),
#  (array([56, 59, 60, 57, 62, 63, 61, 58, 49, 54], dtype=int32),
#   array([1.7881393e-07, 8.1424809e-01, 8.7381738e-01, 9.0672714e-01,
#          9.2201424e-01, 9.2267525e-01, 9.3777740e-01, 9.3946594e-01,
#          9.6678942e-01, 9.7086000e-01], dtype=float32)),
#  (array([ 57,  59,  58,  63,  61,  56,  62,  60, 376, 347], dtype=int32),
#   array([0.        , 0.8274268 , 0.84560156, 0.9026711 , 0.9064577 ,
#          0.90672714, 0.9213912 , 0.9286341 , 0.9717353 , 0.9735464 ],
#         dtype=float32)),
#  (array([ 58,  57,  63,  59,  56,  62,  61,  60, 802,  98], dtype=int32),
#   array([0.        , 0.84560156, 0.9011236 , 0.9306607 , 0.93946594,
#          0.9489829 , 0.95655376, 0.95836234, 0.96384144, 0.97111225],
#         dtype=float32)),
#  (array([59, 56, 57, 60, 63, 62, 61, 58, 54, 52], dtype=int32),
#   array([0.        , 0.8142481 , 0.8274268 , 0.8554631 , 0.89365375,
#          0.9106706 , 0.9287266 , 0.9306607 , 0.9574117 , 0.9732156 ],
#         dtype=float32)),
#  (array([ 60,  59,  56,  57,  61,  63,  62, 471,  58, 882], dtype=int32),
#   array([0.        , 0.8554631 , 0.8738174 , 0.9286341 , 0.9293924 ,
#          0.93956405, 0.9497428 , 0.9556245 , 0.95836234, 0.9616291 ],
#         dtype=float32)),
#  (array([ 61,  57,  63,  59,  60,  62,  56,  58, 946, 405], dtype=int32),
#   array([0.        , 0.9064577 , 0.91934484, 0.9287266 , 0.9293924 ,
#          0.9329289 , 0.9377774 , 0.95655376, 0.9700474 , 0.9718408 ],
#         dtype=float32)),
#  (array([ 62,  63,  59,  57,  56,  61,  58,  60, 398, 941], dtype=int32),
#   array([0.        , 0.9037545 , 0.9106706 , 0.9213912 , 0.92201424,
#          0.9329289 , 0.9489829 , 0.9497428 , 0.9537766 , 0.95389116],
#         dtype=float32)),
#  (array([ 63,  59,  58,  57,  62,  61,  56,  60, 412, 590], dtype=int32),
#   array([1.1920929e-07, 8.9365375e-01, 9.0112358e-01, 9.0267110e-01,
#          9.0375447e-01, 9.1934484e-01, 9.2267525e-01, 9.3956405e-01,
#          9.7135055e-01, 9.7216189e-01], dtype=float32)),
#  (array([ 64, 698, 732, 565, 389, 935, 456, 472, 539, 517], dtype=int32),
#   array([1.7881393e-07, 9.6869349e-01, 9.6902245e-01, 9.7595978e-01,
#          9.7805405e-01, 9.7841328e-01, 9.7851145e-01, 9.7853816e-01,
#          9.7869319e-01, 9.7963840e-01], dtype=float32)),
#  (array([ 65, 312, 906, 135, 682, 845, 292, 263,  89, 994], dtype=int32),
#   array([0.       , 0.9677063, 0.9748032, 0.9751669, 0.9753809, 0.9770601,
#          0.9771791, 0.9796802, 0.980279 , 0.9832061], dtype=float32)),
#  (array([ 66, 126, 297,   8, 459, 751, 499, 415, 842, 775], dtype=int32),
#   array([1.1920929e-07, 9.7625899e-01, 9.8003340e-01, 9.8023814e-01,
#          9.8153621e-01, 9.8223490e-01, 9.8235375e-01, 9.8263884e-01,
#          9.8294497e-01, 9.8364264e-01], dtype=float32)),
#  (array([ 67, 106, 762, 733, 805, 154, 888, 705, 682, 751], dtype=int32),
#   array([2.3841858e-07, 9.3974942e-01, 9.3991178e-01, 9.5687973e-01,
#          9.6139705e-01, 9.6220624e-01, 9.6283358e-01, 9.6388251e-01,
#          9.6612877e-01, 9.6667188e-01], dtype=float32)),
#  (array([ 68,  96, 597,  91, 680, 958, 117, 591, 662, 727], dtype=int32),
#   array([0.        , 0.83825314, 0.9486136 , 0.9494966 , 0.962419  ,
#          0.964123  , 0.9663254 , 0.9687275 , 0.9717255 , 0.9727737 ],
#         dtype=float32)),
#  (array([ 69, 587, 497, 706, 912,  30, 992, 860, 822, 726], dtype=int32),
#   array([0.        , 0.97101015, 0.97587   , 0.979142  , 0.98005617,
#          0.98180676, 0.9827172 , 0.98280865, 0.9839398 , 0.984403  ],
#         dtype=float32)),
#  (array([ 70, 648, 431,  95,  32,  55, 850, 852, 851, 782], dtype=int32),
#   array([0.        , 0.8569463 , 0.8928224 , 0.94545144, 0.95561945,
#          0.9561442 , 0.9633659 , 0.9646358 , 0.96471375, 0.9728822 ],
#         dtype=float32)),
#  (array([ 71, 102, 509, 671, 350, 868, 219, 833, 419,  34], dtype=int32),
#   array([0.        , 0.83753157, 0.8909197 , 0.9245021 , 0.9457921 ,
#          0.94827175, 0.95170325, 0.9571763 , 0.9595384 , 0.9755069 ],
#         dtype=float32)),
#  (array([ 72, 598, 608, 134, 989, 186, 129, 797, 649, 958], dtype=int32),
#   array([0.        , 0.9667217 , 0.9704163 , 0.9709732 , 0.97398823,
#          0.9745623 , 0.9807741 , 0.9811071 , 0.9812396 , 0.98127913],
#         dtype=float32)),
#  (array([ 73, 198, 973, 291, 732, 798, 208, 627, 825, 158], dtype=int32),
#   array([0.        , 0.9183724 , 0.94606364, 0.95866823, 0.9674723 ,
#          0.9677784 , 0.96990293, 0.972594  , 0.97602576, 0.9763761 ],
#         dtype=float32)),
#  (array([ 74, 466, 184, 814, 957, 607, 483, 380, 647,   3], dtype=int32),
#   array([2.9802322e-07, 9.6195245e-01, 9.6196747e-01, 9.6299630e-01,
#          9.6339756e-01, 9.6422535e-01, 9.6548814e-01, 9.6754414e-01,
#          9.6919042e-01, 9.6934712e-01], dtype=float32)),
#  (array([ 75, 939,  33, 961, 882, 997, 670, 762, 855, 412], dtype=int32),
#   array([0.        , 0.9408817 , 0.9548739 , 0.9753796 , 0.97630644,
#          0.9767007 , 0.97683597, 0.97778285, 0.9784121 , 0.9787039 ],
#         dtype=float32)),
#  (array([ 76, 803, 943, 768, 831, 691, 535,   0,  98, 937], dtype=int32),
#   array([0.        , 0.9451972 , 0.94974256, 0.9604777 , 0.9619702 ,
#          0.96252525, 0.96326536, 0.9643083 , 0.96785206, 0.9712027 ],
#         dtype=float32)),
#  (array([ 77, 861, 104, 581, 595, 145, 416, 780, 965, 481], dtype=int32),
#   array([0.        , 0.8384101 , 0.9636345 , 0.9647631 , 0.96524   ,
#          0.96548545, 0.9688695 , 0.9697333 , 0.9699011 , 0.97044015],
#         dtype=float32)),
#  (array([ 78,  79, 166, 592, 128, 652, 788, 438, 383, 691], dtype=int32),
#   array([0.        , 0.12986404, 0.9404079 , 0.9710451 , 0.9766298 ,
#          0.9780399 , 0.9794594 , 0.9805363 , 0.98061043, 0.9808815 ],
#         dtype=float32)),
#  (array([ 79,  78, 166, 592, 239, 128, 852, 652, 788, 438], dtype=int32),
#   array([0.        , 0.12986404, 0.9428451 , 0.9722293 , 0.97644585,
#          0.97758555, 0.97857046, 0.97893804, 0.9802995 , 0.9813323 ],
#         dtype=float32)),
#  (array([ 80, 739, 279, 937,  38, 702, 782, 859, 452,  73], dtype=int32),
#   array([3.5762787e-07, 9.3829161e-01, 9.3904763e-01, 9.5445406e-01,
#          9.6432084e-01, 9.7635156e-01, 9.7636789e-01, 9.7970414e-01,
#          9.8029739e-01, 9.8048216e-01], dtype=float32)),
#  (array([ 81, 802, 114, 916, 110, 264, 690, 891, 401, 492], dtype=int32),
#   array([0.        , 0.93995917, 0.9420026 , 0.9462136 , 0.9644637 ,
#          0.9680356 , 0.9748051 , 0.9750936 , 0.97859234, 0.9793032 ],
#         dtype=float32)),
#  (array([ 82, 620, 137, 315, 970, 817, 382, 579, 926, 131], dtype=int32),
#   array([0.        , 0.91553676, 0.9194522 , 0.95259714, 0.9539434 ,
#          0.9546459 , 0.9553543 , 0.955948  , 0.95834064, 0.96090186],
#         dtype=float32)),
#  (array([ 83,  55, 366, 648, 342, 657,  95, 400, 280, 968], dtype=int32),
#   array([0.        , 0.9527625 , 0.95815206, 0.9589447 , 0.9618041 ,
#          0.97112286, 0.9723547 , 0.97411406, 0.97488207, 0.9761671 ],
#         dtype=float32)),
#  (array([ 84, 490, 687, 429, 530, 166, 644, 718, 829, 310], dtype=int32),
#   array([2.3841858e-07, 9.7014791e-01, 9.7126561e-01, 9.7156197e-01,
#          9.7224867e-01, 9.7387147e-01, 9.7514611e-01, 9.7551501e-01,
#          9.7587556e-01, 9.7696286e-01], dtype=float32)),
#  (array([ 85, 364, 848, 700, 843, 106, 738, 423, 561, 132], dtype=int32),
#   array([2.9802322e-07, 9.5410645e-01, 9.7132689e-01, 9.7262824e-01,
#          9.7320795e-01, 9.7485536e-01, 9.7548091e-01, 9.7601366e-01,
#          9.7780013e-01, 9.7860014e-01], dtype=float32)),
#  (array([ 86, 984, 937, 358, 401, 479, 777, 477, 619, 783], dtype=int32),
#   array([0.        , 0.9269071 , 0.96585035, 0.9680492 , 0.9680987 ,
#          0.96974784, 0.97275394, 0.9729999 , 0.9747155 , 0.97550416],
#         dtype=float32)),
#  (array([ 87, 214, 216, 414, 555, 933,   4, 413, 149, 596], dtype=int32),
#   array([0.        , 0.96434623, 0.9662111 , 0.96735233, 0.96739155,
#          0.9703377 , 0.9708887 , 0.97766894, 0.9788615 , 0.9804674 ],
#         dtype=float32)),
#  (array([ 88, 740, 693, 361, 179, 815, 629, 371, 686, 152], dtype=int32),
#   array([0.        , 0.96095437, 0.9673945 , 0.9746642 , 0.9812955 ,
#          0.9818236 , 0.9836056 , 0.9847039 , 0.98504025, 0.98560756],
#         dtype=float32)),
#  (array([ 89, 163, 751, 386, 988,  39, 459, 762, 845, 862], dtype=int32),
#   array([1.7881393e-07, 9.6191055e-01, 9.6386284e-01, 9.6516156e-01,
#          9.6619445e-01, 9.6897817e-01, 9.7229445e-01, 9.7278059e-01,
#          9.7367704e-01, 9.7671241e-01], dtype=float32)),
#  (array([ 90, 157, 277, 380, 177, 204, 382, 236, 175, 648], dtype=int32),
#   array([0.        , 0.9664921 , 0.97302794, 0.978979  , 0.97976184,
#          0.9804445 , 0.98143154, 0.981762  , 0.98202664, 0.9820471 ],
#         dtype=float32)),
#  (array([ 91, 523, 255,  42, 922,  68,  41,  99, 731, 969], dtype=int32),
#   array([0.        , 0.932507  , 0.9350461 , 0.93540585, 0.9357784 ,
#          0.9494966 , 0.952011  , 0.96552   , 0.9656026 , 0.9671419 ],
#         dtype=float32)),
#  (array([ 92, 713,  97, 396, 633, 502, 980, 114, 827, 661], dtype=int32),
#   array([0.        , 0.9461005 , 0.95837975, 0.96327865, 0.96845   ,
#          0.9695837 , 0.97282034, 0.9736454 , 0.97535783, 0.97546655],
#         dtype=float32)),
#  (array([ 93, 825, 917, 369, 115, 138, 370, 584, 183, 227], dtype=int32),
#   array([2.9802322e-07, 9.4290477e-01, 9.4679922e-01, 9.4914186e-01,
#          9.5069569e-01, 9.6824336e-01, 9.7024238e-01, 9.7131413e-01,
#          9.7154719e-01, 9.7380084e-01], dtype=float32)),
#  (array([ 94, 829, 513, 499, 921, 329, 191, 573, 543, 405], dtype=int32),
#   array([1.1920929e-07, 9.4610983e-01, 9.4908828e-01, 9.5298386e-01,
#          9.5391369e-01, 9.5609862e-01, 9.5642674e-01, 9.6471381e-01,
#          9.6718466e-01, 9.6932924e-01], dtype=float32)),
#  (array([ 95, 648,  70, 912, 439, 119, 385,  83, 498, 761], dtype=int32),
#   array([1.1920929e-07, 9.4545007e-01, 9.4545144e-01, 9.5321703e-01,
#          9.5955354e-01, 9.6729857e-01, 9.6945244e-01, 9.7235471e-01,
#          9.8012477e-01, 9.8023748e-01], dtype=float32)),
#  (array([ 96,  68, 463, 117, 285, 149, 653,  40, 125, 726], dtype=int32),
#   array([0.        , 0.83825314, 0.9627635 , 0.9705679 , 0.9743842 ,
#          0.9796588 , 0.9809432 , 0.9812992 , 0.9814865 , 0.98198855],
#         dtype=float32)),
#  (array([ 97, 673, 202, 614, 628,  92, 437, 127, 595, 875], dtype=int32),
#   array([0.        , 0.90765274, 0.9140969 , 0.9392019 , 0.94004935,
#          0.95837975, 0.95839995, 0.97579086, 0.9760515 , 0.97627234],
#         dtype=float32)),
#  (array([ 98, 691, 887,  76, 924, 936,  58, 937, 588,  63], dtype=int32),
#   array([1.1920929e-07, 9.4072676e-01, 9.6487796e-01, 9.6785206e-01,
#          9.6842700e-01, 9.7053879e-01, 9.7111225e-01, 9.7129685e-01,
#          9.7328609e-01, 9.7366190e-01], dtype=float32)),
#  (array([ 99, 491, 469, 839,  91, 994, 731, 692, 264, 276], dtype=int32),
#   array([2.9802322e-07, 9.5111865e-01, 9.5219249e-01, 9.6028000e-01,
#          9.6552002e-01, 9.6867621e-01, 9.7172010e-01, 9.7453040e-01,
#          9.7593147e-01, 9.7649431e-01], dtype=float32)),
#  (array([100, 132, 424, 539, 937, 535, 835, 486, 699, 749], dtype=int32),
#   array([0.        , 0.96252316, 0.9635719 , 0.96836436, 0.9703553 ,
#          0.97278005, 0.97364384, 0.9742468 , 0.9762774 , 0.9781227 ],
#         dtype=float32)),
#  (array([101, 389, 762,  59, 884, 615, 447, 448, 218, 162], dtype=int32),
#   array([0.        , 0.9427963 , 0.9686449 , 0.97815824, 0.9800196 ,
#          0.9801159 , 0.98032546, 0.9808983 , 0.98094106, 0.9813413 ],
#         dtype=float32)),
#  (array([102,  71, 671, 350, 999, 833, 419, 219, 868, 165], dtype=int32),
#   array([0.        , 0.83753157, 0.94978744, 0.95071524, 0.96497047,
#          0.9715186 , 0.9730896 , 0.9741325 , 0.9741972 , 0.97523904],
#         dtype=float32)),
#  (array([103, 232, 112, 667, 253, 975, 194, 683, 521, 976], dtype=int32),
#   array([0.        , 0.95400953, 0.96754515, 0.9682661 , 0.9685356 ,
#          0.9691299 , 0.97354627, 0.9736067 , 0.97619474, 0.97661936],
#         dtype=float32)),
#  (array([104,  34,  39, 868, 780, 525, 595,  77, 861, 124], dtype=int32),
#   array([5.9604645e-08, 8.4613687e-01, 9.2857742e-01, 9.3150842e-01,
#          9.4546610e-01, 9.6092761e-01, 9.6271610e-01, 9.6363449e-01,
#          9.6678668e-01, 9.6943027e-01], dtype=float32)),
#  (array([105, 621, 515, 904, 449, 572,  82, 445, 733, 244], dtype=int32),
#   array([1.1920929e-07, 9.6723771e-01, 9.7586119e-01, 9.7767484e-01,
#          9.7858727e-01, 9.7984487e-01, 9.8003244e-01, 9.8014051e-01,
#          9.8042905e-01, 9.8048770e-01], dtype=float32)),
#  (array([106, 479,  67, 855, 888, 530, 254, 259, 221,  23], dtype=int32),
#   array([0.        , 0.93921316, 0.9397494 , 0.95978904, 0.9606709 ,
#          0.9631564 , 0.9633598 , 0.9649612 , 0.96496934, 0.9662926 ],
#         dtype=float32)),
#  (array([107, 246, 576, 502, 650, 157, 364, 129, 740, 990], dtype=int32),
#   array([0.        , 0.9410382 , 0.97525376, 0.9755864 , 0.9769973 ,
#          0.97719556, 0.97771245, 0.9777263 , 0.97834575, 0.97867537],
#         dtype=float32)),
#  (array([108,  35,   1, 803, 396, 943, 648, 970, 465, 176], dtype=int32),
#   array([0.        , 0.94883573, 0.969903  , 0.97246224, 0.9743024 ,
#          0.97757393, 0.97782177, 0.9779279 , 0.97845346, 0.9790639 ],
#         dtype=float32)),
#  (array([109, 363, 963, 351,  16, 646, 832, 742, 507, 554], dtype=int32),
#   array([0.        , 0.9659421 , 0.97075313, 0.97374254, 0.97412056,
#          0.9747797 , 0.9778591 , 0.9790931 , 0.9808216 , 0.98103255],
#         dtype=float32)),
#  (array([110, 900, 865, 298, 266,  81, 524, 465, 179, 622], dtype=int32),
#   array([3.5762787e-07, 9.3837547e-01, 9.5186007e-01, 9.5793217e-01,
#          9.6347684e-01, 9.6446371e-01, 9.6532691e-01, 9.6535313e-01,
#          9.7109890e-01, 9.7241133e-01], dtype=float32)),
#  (array([111, 763, 752, 829,  44,  41,  53, 705,  94, 911], dtype=int32),
#   array([0.        , 0.91576046, 0.922539  , 0.9632782 , 0.9659652 ,
#          0.96861887, 0.9696226 , 0.9718828 , 0.9735567 , 0.9755734 ],
#         dtype=float32)),
#  (array([112,  38, 181, 543, 103, 306, 190, 355, 313, 999], dtype=int32),
#   array([0.        , 0.9108663 , 0.95404375, 0.95622456, 0.96754515,
#          0.97147274, 0.9729145 , 0.9735602 , 0.97359824, 0.9738442 ],
#         dtype=float32)),
#  (array([113, 146,  31, 973, 226, 377, 655, 796, 144, 679], dtype=int32),
#   array([2.9802322e-07, 9.4553232e-01, 9.5737660e-01, 9.6433830e-01,
#          9.6442419e-01, 9.6820116e-01, 9.7036874e-01, 9.7326761e-01,
#          9.7442216e-01, 9.7445220e-01], dtype=float32)),
#  (array([114, 559,  81, 916,  92, 765, 340, 149, 919, 876], dtype=int32),
#   array([0.        , 0.9258136 , 0.9420026 , 0.96235394, 0.9736454 ,
#          0.97696066, 0.97700006, 0.9773233 , 0.97858703, 0.97868115],
#         dtype=float32)),
#  (array([115,  93, 798, 343, 360, 641, 287, 825, 917, 538], dtype=int32),
#   array([0.        , 0.9506957 , 0.951917  , 0.96893525, 0.96990025,
#          0.97268933, 0.9727667 , 0.9737133 , 0.9755063 , 0.9758728 ],
#         dtype=float32)),
#  (array([116, 593, 155, 535, 446, 595, 743, 451, 151, 985], dtype=int32),
#   array([0.        , 0.94279444, 0.9597741 , 0.9654603 , 0.96727604,
#          0.97162455, 0.9717392 , 0.9723344 , 0.9725635 , 0.9728856 ],
#         dtype=float32)),
#  (array([117, 519, 867,  68,  96, 497, 724, 964, 367, 908], dtype=int32),
#   array([0.        , 0.95901597, 0.96308875, 0.9663254 , 0.9705679 ,
#          0.97528476, 0.97596353, 0.97631913, 0.97662985, 0.97717893],
#         dtype=float32)),
#  (array([118, 734, 438, 774, 664, 284, 735, 146, 651, 652], dtype=int32),
#   array([5.9604645e-08, 9.5083141e-01, 9.6581191e-01, 9.6718055e-01,
#          9.6740496e-01, 9.6783596e-01, 9.6847194e-01, 9.6863192e-01,
#          9.6984410e-01, 9.7173059e-01], dtype=float32)),
#  (array([119, 973, 772, 957, 339, 783, 666, 468, 147, 261], dtype=int32),
#   array([0.        , 0.9284998 , 0.93213665, 0.9481112 , 0.9503967 ,
#          0.95046157, 0.9507229 , 0.9533752 , 0.9572824 , 0.9613449 ],
#         dtype=float32)),
#  (array([120, 936, 377, 132, 564, 588, 786, 475, 965, 214], dtype=int32),
#   array([2.9802322e-07, 9.2506158e-01, 9.6905482e-01, 9.7476578e-01,
#          9.7581619e-01, 9.7641134e-01, 9.7679663e-01, 9.7810602e-01,
#          9.8029262e-01, 9.8141199e-01], dtype=float32)),
#  (array([121, 546, 517, 929, 971, 855, 854, 241, 610,  50], dtype=int32),
#   array([0.        , 0.9561025 , 0.9705667 , 0.97114676, 0.97380066,
#          0.977436  , 0.977577  , 0.9789683 , 0.9799478 , 0.98024094],
#         dtype=float32)),
#  (array([122, 402, 619, 150, 862, 711,  12, 907, 991, 866], dtype=int32),
#   array([0.        , 0.93276745, 0.9602107 , 0.964766  , 0.96639234,
#          0.96737415, 0.96743983, 0.96762675, 0.96770287, 0.96817595],
#         dtype=float32)),
#  (array([123,  24, 288, 620, 444, 318, 647, 772, 446, 166], dtype=int32),
#   array([0.        , 0.9157403 , 0.9377102 , 0.964919  , 0.9655692 ,
#          0.96559477, 0.9658377 , 0.9722041 , 0.97395676, 0.9749243 ],
#         dtype=float32)),
#  (array([124, 780, 405, 460, 710, 927, 104, 733,  39, 252], dtype=int32),
#   array([2.3841858e-07, 9.4736117e-01, 9.6194381e-01, 9.6466827e-01,
#          9.6540827e-01, 9.6819407e-01, 9.6943027e-01, 9.7292215e-01,
#          9.7507280e-01, 9.7706920e-01], dtype=float32)),
#  (array([125, 243, 639, 915, 559, 860, 391, 457, 462, 700], dtype=int32),
#   array([0.        , 0.9691914 , 0.9692146 , 0.9728538 , 0.973317  ,
#          0.97444254, 0.97636956, 0.97729164, 0.9780507 , 0.97820055],
#         dtype=float32)),
#  (array([126, 694, 855, 356, 257, 930,  66,  47, 784, 824], dtype=int32),
#   array([5.9604645e-08, 9.6242464e-01, 9.6590185e-01, 9.7450697e-01,
#          9.7576123e-01, 9.7590536e-01, 9.7625899e-01, 9.7710145e-01,
#          9.7791624e-01, 9.7826874e-01], dtype=float32)),
#  (array([127, 747, 524, 919, 905, 894, 362, 656, 849,  97], dtype=int32),
#   array([1.7881393e-07, 9.4454610e-01, 9.5699984e-01, 9.6753895e-01,
#          9.7165662e-01, 9.7177988e-01, 9.7381711e-01, 9.7397369e-01,
#          9.7438264e-01, 9.7579086e-01], dtype=float32)),
#  (array([128, 665, 496, 922, 296, 604,  78, 122, 384,  79], dtype=int32),
#   array([0.        , 0.96360636, 0.973069  , 0.97361565, 0.9746094 ,
#          0.97464424, 0.9766298 , 0.9772423 , 0.97756636, 0.97758555],
#         dtype=float32)),
#  (array([129, 817, 702, 971,  22, 693, 491, 884, 797, 897], dtype=int32),
#   array([0.        , 0.9260453 , 0.95927715, 0.96598995, 0.96892184,
#          0.971478  , 0.9731291 , 0.9731588 , 0.9750752 , 0.9755019 ],
#         dtype=float32)),
#  (array([130, 197, 394, 166, 887, 220,  30, 829, 186, 409], dtype=int32),
#   array([0.        , 0.91100997, 0.92387897, 0.9273946 , 0.93788385,
#          0.9476361 , 0.9486519 , 0.95031345, 0.95661414, 0.9649262 ],
#         dtype=float32)),
#  (array([131, 620, 137, 230,  82, 315, 970, 817, 382, 579], dtype=int32),
#   array([0.        , 0.93317187, 0.93626976, 0.9605765 , 0.96090186,
#          0.96249443, 0.96355957, 0.9641154 , 0.96467584, 0.96514565],
#         dtype=float32)),
#  (array([132, 813, 391, 100, 539,  39, 955, 540, 786, 481], dtype=int32),
#   array([0.        , 0.9497127 , 0.95038295, 0.96252316, 0.9649351 ,
#          0.96771574, 0.96897936, 0.97122204, 0.9715351 , 0.97445256],
#         dtype=float32)),
#  (array([133, 351, 542,  14, 559, 481, 496,  35, 980, 936], dtype=int32),
#   array([2.3841858e-07, 9.3964946e-01, 9.7107452e-01, 9.7136867e-01,
#          9.7465998e-01, 9.7819281e-01, 9.7876728e-01, 9.7911149e-01,
#          9.7932607e-01, 9.8130989e-01], dtype=float32)),
#  (array([134, 608, 381,  72, 376, 318,  12, 358,   2, 625], dtype=int32),
#   array([0.        , 0.9304471 , 0.9661648 , 0.9709732 , 0.9734133 ,
#          0.9786129 , 0.9794721 , 0.97965306, 0.98006594, 0.9807038 ],
#         dtype=float32)),
#  (array([135,  65, 463, 486, 175, 264, 913, 500, 834, 706], dtype=int32),
#   array([0.        , 0.9751669 , 0.9806748 , 0.9807421 , 0.98131645,
#          0.98146677, 0.9834234 , 0.98392224, 0.98398596, 0.98418736],
#         dtype=float32)),
#  (array([136, 445, 596, 635, 776, 701, 285, 746, 245, 250], dtype=int32),
#   array([0.        , 0.9306819 , 0.95212865, 0.9582235 , 0.96117723,
#          0.97024333, 0.9711479 , 0.97334427, 0.97414005, 0.97483945],
#         dtype=float32)),
#  (array([137, 620, 817, 382,  82, 315, 970, 579, 926, 131], dtype=int32),
#   array([2.3841858e-07, 8.5815084e-01, 9.1757494e-01, 9.1858923e-01,
#          9.1945219e-01, 9.2273301e-01, 9.2492741e-01, 9.2819494e-01,
#          9.3209499e-01, 9.3626976e-01], dtype=float32)),
#  (array([138, 679, 774, 825,  15,  93, 251, 483, 284, 285], dtype=int32),
#   array([0.        , 0.9503686 , 0.9530516 , 0.95703787, 0.9655843 ,
#          0.96824336, 0.9690719 , 0.9697007 , 0.9698818 , 0.9707797 ],
#         dtype=float32)),
#  (array([139, 928, 742, 908, 915, 158, 170, 130,  15, 520], dtype=int32),
#   array([2.3841858e-07, 9.3768770e-01, 9.4429195e-01, 9.7881460e-01,
#          9.7931373e-01, 9.8002046e-01, 9.8029834e-01, 9.8061556e-01,
#          9.8079920e-01, 9.8092359e-01], dtype=float32)),
#  (array([140, 673, 434, 616, 163, 894, 825, 355, 190, 349], dtype=int32),
#   array([2.3841858e-07, 9.4045132e-01, 9.4370031e-01, 9.5152873e-01,
#          9.5625818e-01, 9.6162844e-01, 9.6291494e-01, 9.6489108e-01,
#          9.6721029e-01, 9.6765471e-01], dtype=float32)),
#  (array([141, 228, 608, 816, 373,  35, 335, 350, 358, 513], dtype=int32),
#   array([0.        , 0.9490067 , 0.9510844 , 0.9638921 , 0.96444416,
#          0.9717098 , 0.9719532 , 0.9724901 , 0.9725816 , 0.9737578 ],
#         dtype=float32)),
#  (array([142, 329, 261, 172, 458, 891, 513,  35, 315, 473], dtype=int32),
#   array([0.        , 0.9546516 , 0.9641671 , 0.97181165, 0.97498566,
#          0.9770364 , 0.9787854 , 0.98031366, 0.9807795 , 0.98079276],
#         dtype=float32)),
#  (array([143, 380, 881,  28, 941, 559, 644, 530, 522, 100], dtype=int32),
#   array([1.7881393e-07, 9.6503329e-01, 9.7175241e-01, 9.7217470e-01,
#          9.7326732e-01, 9.7717553e-01, 9.7727507e-01, 9.7972018e-01,
#          9.8074114e-01, 9.8102188e-01], dtype=float32)),
#  (array([144, 146, 145, 199, 352, 569, 951, 830, 739, 333], dtype=int32),
#   array([0.        , 0.9090003 , 0.92618644, 0.9477129 , 0.95694125,
#          0.96225536, 0.9633487 , 0.96399677, 0.9647166 , 0.96856946],
#         dtype=float32)),
#  (array([145, 146, 144,  77, 628, 603,  27, 281, 679, 821], dtype=int32),
#   array([0.        , 0.86628157, 0.92618644, 0.96548545, 0.9681856 ,
#          0.96842396, 0.97027695, 0.97162056, 0.9754628 , 0.9767037 ],
#         dtype=float32)),
#  (array([146, 145, 144, 796, 113,  31, 898, 725, 655, 118], dtype=int32),
#   array([1.1920929e-07, 8.6628157e-01, 9.0900028e-01, 9.1857857e-01,
#          9.4553232e-01, 9.5137918e-01, 9.5943171e-01, 9.6550435e-01,
#          9.6619940e-01, 9.6863192e-01], dtype=float32)),
#  (array([147, 119, 957, 339, 783, 973, 468, 113, 293, 308], dtype=int32),
#   array([4.1723251e-07, 9.5728242e-01, 9.6039623e-01, 9.6214062e-01,
#          9.6219015e-01, 9.6388733e-01, 9.6441394e-01, 9.7627634e-01,
#          9.7971433e-01, 9.8084193e-01], dtype=float32)),
#  (array([148, 632, 495, 977, 197, 438, 837, 777,  73, 651], dtype=int32),
#   array([0.        , 0.9275957 , 0.95844907, 0.97385484, 0.9741327 ,
#          0.9743413 , 0.9746226 , 0.976838  , 0.9786534 , 0.97955775],
#         dtype=float32)),
#  (array([149, 114, 904,  87, 559,  96, 856, 127, 299, 657], dtype=int32),
#   array([0.       , 0.9773233, 0.9778122, 0.9788615, 0.9794006, 0.9796588,
#          0.9803532, 0.9812619, 0.9826211, 0.9828112], dtype=float32)),
#  (array([150, 687, 346,  48, 534, 122, 318, 467, 490, 191], dtype=int32),
#   array([0.        , 0.9414762 , 0.94565815, 0.9489305 , 0.95563716,
#          0.964766  , 0.9650322 , 0.9708175 , 0.9716752 , 0.97281057],
#         dtype=float32)),
#  (array([151, 628, 451, 593, 232, 319, 743, 985, 914, 483], dtype=int32),
#   array([0.        , 0.9520285 , 0.95762664, 0.96350026, 0.96418417,
#          0.9671182 , 0.96723837, 0.9685674 , 0.9686483 , 0.96869045],
#         dtype=float32)),
#  (array([152, 887, 733, 928, 173, 471, 957, 595, 884, 742], dtype=int32),
#   array([0.        , 0.97605217, 0.97998315, 0.9812012 , 0.9820902 ,
#          0.9825698 , 0.98272336, 0.9829922 , 0.98311025, 0.9833405 ],
#         dtype=float32)),
#  (array([153, 755, 234, 286, 664, 247, 145, 534, 413, 874], dtype=int32),
#   array([2.3841858e-07, 9.6811813e-01, 9.6989858e-01, 9.7434020e-01,
#          9.7475207e-01, 9.7764224e-01, 9.7809231e-01, 9.7962093e-01,
#          9.7978604e-01, 9.8073679e-01], dtype=float32)),
#  (array([154,  27, 803,  67, 805, 218, 517, 553, 305, 344], dtype=int32),
#   array([2.9802322e-07, 9.3428534e-01, 9.5922285e-01, 9.6220624e-01,
#          9.6263778e-01, 9.6279693e-01, 9.6604341e-01, 9.6768343e-01,
#          9.6792597e-01, 9.7434741e-01], dtype=float32)),
#  (array([155, 448, 116, 636, 861, 651, 595, 598, 441, 269], dtype=int32),
#   array([0.        , 0.9526999 , 0.9597741 , 0.96875817, 0.9702829 ,
#          0.97482866, 0.978922  , 0.9792622 , 0.9802857 , 0.98037654],
#         dtype=float32)),
#  (array([156, 402, 469, 270, 665, 750, 287, 540, 251, 824], dtype=int32),
#   array([0.        , 0.9505561 , 0.96267384, 0.9731896 , 0.97756463,
#          0.97809976, 0.9790938 , 0.97973037, 0.98035395, 0.9812704 ],
#         dtype=float32)),
#  (array([157,  90, 457, 515, 311, 277, 107, 752, 650, 483], dtype=int32),
#   array([2.9802322e-07, 9.6649212e-01, 9.6661663e-01, 9.7034657e-01,
#          9.7085607e-01, 9.7119343e-01, 9.7719556e-01, 9.7841680e-01,
#          9.7893769e-01, 9.7935069e-01], dtype=float32)),
#  (array([158, 385, 225, 704, 459, 333, 740, 477, 654, 674], dtype=int32),
#   array([1.1920929e-07, 9.3421835e-01, 9.5520931e-01, 9.5820415e-01,
#          9.6235734e-01, 9.6899009e-01, 9.7232229e-01, 9.7473246e-01,
#          9.7566926e-01, 9.7578979e-01], dtype=float32)),
#  (array([159, 203,  25, 524, 650, 456,  73, 227, 489, 513], dtype=int32),
#   array([0.        , 0.971296  , 0.9726379 , 0.9775935 , 0.97994155,
#          0.98019975, 0.9802625 , 0.98062795, 0.9824126 , 0.9825024 ],
#         dtype=float32)),
#  (array([160, 342, 908, 514,  43, 894, 244, 373, 685, 582], dtype=int32),
#   array([1.1920929e-07, 9.6075654e-01, 9.7310311e-01, 9.7488618e-01,
#          9.7740048e-01, 9.7758824e-01, 9.7853041e-01, 9.8076224e-01,
#          9.8107135e-01, 9.8157227e-01], dtype=float32)),
#  (array([161, 377, 552, 779, 343, 936, 671, 882, 719, 816], dtype=int32),
#   array([0.        , 0.95612407, 0.9626751 , 0.96410507, 0.9674377 ,
#          0.97390467, 0.97401613, 0.9759738 , 0.9772322 , 0.97781783],
#         dtype=float32)),
#  (array([162, 355, 190, 507, 140, 754, 781, 660, 615,   4], dtype=int32),
#   array([0.        , 0.96060413, 0.9705964 , 0.9741139 , 0.97554815,
#          0.9775681 , 0.9776886 , 0.97851485, 0.9788901 , 0.97953033],
#         dtype=float32)),
#  (array([163,  29, 894, 683, 140, 208, 841, 891, 384,  89], dtype=int32),
#   array([2.3841858e-07, 9.5172501e-01, 9.5210952e-01, 9.5383930e-01,
#          9.5625818e-01, 9.5665419e-01, 9.5744419e-01, 9.5745546e-01,
#          9.6080697e-01, 9.6191055e-01], dtype=float32)),
#  (array([164, 657, 811, 380, 887, 204, 132, 834, 469,  39], dtype=int32),
#   array([1.7881393e-07, 9.3538982e-01, 9.6865934e-01, 9.6935409e-01,
#          9.7184539e-01, 9.7433090e-01, 9.7827959e-01, 9.7892421e-01,
#          9.7959960e-01, 9.7984135e-01], dtype=float32)),
#  (array([165, 228, 616, 324, 469, 913, 605, 102, 404, 350], dtype=int32),
#   array([0.        , 0.9714283 , 0.9729519 , 0.9744336 , 0.9744832 ,
#          0.974969  , 0.97513855, 0.97523904, 0.975765  , 0.9759785 ],
#         dtype=float32)),
#  (array([166, 197, 394, 130, 208,  78,  79,  10, 790, 296], dtype=int32),
#   array([0.        , 0.91607857, 0.9170326 , 0.9273946 , 0.93724746,
#          0.9404079 , 0.9428451 , 0.9491973 , 0.96057516, 0.9682368 ],
#         dtype=float32)),
#  (array([167, 345, 957, 745, 523, 869, 929, 127, 923, 776], dtype=int32),
#   array([2.3841858e-07, 9.4976801e-01, 9.7654927e-01, 9.7920412e-01,
#          9.8054302e-01, 9.8101598e-01, 9.8167843e-01, 9.8193127e-01,
#          9.8210615e-01, 9.8217404e-01], dtype=float32)),
#  (array([168, 327, 597, 552, 860, 185, 231, 743, 451, 151], dtype=int32),
#   array([0.        , 0.96004695, 0.9632835 , 0.964928  , 0.9654239 ,
#          0.9663418 , 0.96712923, 0.96914697, 0.9697968 , 0.9700469 ],
#         dtype=float32)),
#  (array([169, 624, 728,  92, 940, 893,  86, 330, 323, 390], dtype=int32),
#   array([0.        , 0.9121437 , 0.9769576 , 0.9791704 , 0.9805805 ,
#          0.98132545, 0.98251575, 0.9826703 , 0.9832979 , 0.9836915 ],
#         dtype=float32)),
#  (array([170, 720,  32, 351, 440, 782, 915, 639, 961, 222], dtype=int32),
#   array([2.3841858e-07, 9.6400136e-01, 9.6683037e-01, 9.6961659e-01,
#          9.7282553e-01, 9.7404146e-01, 9.7491747e-01, 9.7518265e-01,
#          9.7575241e-01, 9.7759151e-01], dtype=float32)),
#  (array([171, 774, 894, 616, 685, 349, 179, 257, 743, 310], dtype=int32),
#   array([0.        , 0.9494203 , 0.95512486, 0.9599954 , 0.962169  ,
#          0.96233094, 0.96255934, 0.96310896, 0.96408963, 0.9656334 ],
#         dtype=float32)),
#  (array([172, 983, 615, 619, 527, 768, 494, 311, 233, 305], dtype=int32),
#   array([0.        , 0.9241602 , 0.93426317, 0.94291365, 0.9523026 ,
#          0.9575912 , 0.9617314 , 0.96878195, 0.97087604, 0.97176194],
#         dtype=float32)),
#  (array([173, 476, 146, 604,   1, 360, 725, 113, 184, 233], dtype=int32),
#   array([5.9604645e-08, 9.6806467e-01, 9.7266442e-01, 9.7331208e-01,
#          9.7484994e-01, 9.7582734e-01, 9.7594488e-01, 9.7603631e-01,
#          9.7686028e-01, 9.7834516e-01], dtype=float32)),
#  (array([174, 993, 750, 614, 394, 882, 417, 464, 244, 922], dtype=int32),
#   array([0.        , 0.95031774, 0.95978105, 0.9610686 , 0.9696488 ,
#          0.97212327, 0.9722108 , 0.97787875, 0.978537  , 0.9793104 ],
#         dtype=float32)),
#  (array([175, 615, 772, 251, 319, 252,  42,  53, 822, 921], dtype=int32),
#   array([0.        , 0.95736986, 0.9592109 , 0.95976657, 0.96163934,
#          0.97350514, 0.97586495, 0.9769815 , 0.9790446 , 0.9792653 ],
#         dtype=float32)),
#  (array([176, 243, 881, 464, 387, 886, 578, 534, 357, 581], dtype=int32),
#   array([0.        , 0.9663303 , 0.96737283, 0.96866584, 0.96883714,
#          0.96914226, 0.9703121 , 0.97036433, 0.97425467, 0.9769816 ],
#         dtype=float32)),
#  (array([177, 663, 786, 285, 212, 652, 993,  90, 102, 754], dtype=int32),
#   array([0.        , 0.89654076, 0.9025808 , 0.9173299 , 0.9507551 ,
#          0.9708536 , 0.9738635 , 0.97976184, 0.97982013, 0.9808389 ],
#         dtype=float32)),
#  (array([178, 998, 264, 490, 400, 594, 475, 242, 206, 521], dtype=int32),
#   array([0.        , 0.9485828 , 0.96473765, 0.96918774, 0.96921575,
#          0.9713948 , 0.97386175, 0.9788485 , 0.9789427 , 0.9790787 ],
#         dtype=float32)),
#  (array([179, 180, 990, 171, 201, 604, 478, 818, 462, 110], dtype=int32),
#   array([0.        , 0.93020016, 0.9512623 , 0.96255934, 0.9657657 ,
#          0.9666118 , 0.96725464, 0.9684645 , 0.9701808 , 0.9710989 ],
#         dtype=float32)),
#  (array([180, 179,  24, 989, 821, 360, 649, 374, 303, 979], dtype=int32),
#   array([0.        , 0.93020016, 0.94300365, 0.9654732 , 0.97463226,
#          0.97786075, 0.9785358 , 0.97858715, 0.97936326, 0.98000014],
#         dtype=float32)),
#  (array([181, 446, 112, 231, 343, 607, 277, 444, 647, 141], dtype=int32),
#   array([1.1920929e-07, 9.4739968e-01, 9.5404375e-01, 9.6482062e-01,
#          9.6800965e-01, 9.7238147e-01, 9.7550589e-01, 9.7618371e-01,
#          9.7890735e-01, 9.8168367e-01], dtype=float32)),
#  (array([182, 824, 353, 757, 702, 118, 462, 992, 125, 220], dtype=int32),
#   array([2.3841858e-07, 9.4703352e-01, 9.5438164e-01, 9.7645766e-01,
#          9.7752368e-01, 9.7752756e-01, 9.7769475e-01, 9.7914261e-01,
#          9.7941226e-01, 9.8026836e-01], dtype=float32)),
#  (array([183, 339, 373, 365, 191,  93, 894, 825, 917, 922], dtype=int32),
#   array([2.9802322e-07, 9.4875228e-01, 9.6814030e-01, 9.6909386e-01,
#          9.7036391e-01, 9.7154719e-01, 9.7208464e-01, 9.7297114e-01,
#          9.7481477e-01, 9.7496384e-01], dtype=float32)),
#  (array([184, 957, 466,  74, 870, 647,   3, 905, 754, 279], dtype=int32),
#   array([2.3841858e-07, 9.4913453e-01, 9.5546955e-01, 9.6196747e-01,
#          9.6371436e-01, 9.6779352e-01, 9.6795738e-01, 9.7308081e-01,
#          9.7329283e-01, 9.7600722e-01], dtype=float32)),
#  (array([185, 749, 168, 231, 743, 451, 151, 985, 914, 483], dtype=int32),
#   array([0.        , 0.9340509 , 0.9663418 , 0.96812904, 0.97008544,
#          0.97071546, 0.970958  , 0.97129893, 0.97137284, 0.97141135],
#         dtype=float32)),
#  (array([186, 130, 887, 220,  30, 829,  72, 824, 886, 654], dtype=int32),
#   array([5.3644180e-07, 9.5661414e-01, 9.6216011e-01, 9.6816051e-01,
#          9.6877813e-01, 9.6978843e-01, 9.7456229e-01, 9.7694057e-01,
#          9.7783369e-01, 9.7914201e-01], dtype=float32)),
#  (array([187, 380, 810, 218, 888, 174, 791,  91, 644, 955], dtype=int32),
#   array([0.        , 0.95154023, 0.9703417 , 0.9788334 , 0.97886676,
#          0.979876  , 0.97991776, 0.9809121 , 0.9810976 , 0.9811409 ],
#         dtype=float32)),
#  (array([188, 312, 661, 329, 214, 423,   6, 779, 540, 193], dtype=int32),
#   array([1.1920929e-07, 9.2505389e-01, 9.5415419e-01, 9.6023947e-01,
#          9.6227717e-01, 9.7247362e-01, 9.7395855e-01, 9.7543103e-01,
#          9.7646070e-01, 9.8129976e-01], dtype=float32)),
#  (array([189, 695, 720, 736, 261, 874, 748, 842, 423, 196], dtype=int32),
#   array([0.        , 0.9196685 , 0.9477871 , 0.9570629 , 0.95983595,
#          0.9721015 , 0.9736791 , 0.9740355 , 0.9753226 , 0.97535306],
#         dtype=float32)),
#  (array([190, 869, 355, 873, 794, 894, 140,  18, 163, 162], dtype=int32),
#   array([0.        , 0.91096216, 0.9577811 , 0.957785  , 0.966622  ,
#          0.9666585 , 0.9672103 , 0.96773434, 0.96921366, 0.9705964 ],
#         dtype=float32)),
#  (array([191, 513, 921, 329,  94, 823, 492, 822, 488, 886], dtype=int32),
#   array([0.        , 0.94849527, 0.95337695, 0.95558727, 0.95642674,
#          0.9605248 , 0.96216965, 0.9643723 , 0.96546096, 0.9671831 ],
#         dtype=float32)),
#  (array([192, 587, 754, 810, 535, 247, 495, 262, 783, 158], dtype=int32),
#   array([0.        , 0.96033114, 0.9604264 , 0.96365964, 0.96725655,
#          0.97141534, 0.97274065, 0.97376215, 0.9774531 , 0.97766227],
#         dtype=float32)),
# ...
#          9.7008312e-01, 9.7039592e-01], dtype=float32)),
#  (array([936, 719, 120, 588, 628, 811,  98, 590, 161, 779], dtype=int32),
#   array([0.        , 0.9120236 , 0.9250616 , 0.95215297, 0.9535774 ,
#          0.968381  , 0.9705388 , 0.9707208 , 0.97390467, 0.9772166 ],
#         dtype=float32)),
#  (array([937, 938, 941, 940, 939, 422, 765,  80, 780,  86], dtype=int32),
#   array([5.9604645e-08, 8.0588555e-01, 8.1068230e-01, 8.1542671e-01,
#          8.1801134e-01, 9.4822460e-01, 9.5093119e-01, 9.5445406e-01,
#          9.6324021e-01, 9.6585035e-01], dtype=float32)),
#  (array([938, 941, 937, 940, 939, 331, 600, 811, 473, 560], dtype=int32),
#   array([1.7881393e-07, 8.0201417e-01, 8.0588555e-01, 8.0697578e-01,
#          8.1541109e-01, 9.4929594e-01, 9.5092249e-01, 9.6935600e-01,
#          9.7362298e-01, 9.7401059e-01], dtype=float32)),
#  (array([939, 938, 940, 937, 941,  75, 241, 753, 252, 506], dtype=int32),
#   array([0.        , 0.8154111 , 0.81541306, 0.81801134, 0.8201458 ,
#          0.9408817 , 0.9669046 , 0.9722084 , 0.9765512 , 0.97763705],
#         dtype=float32)),
#  (array([940, 941, 938, 939, 937,  34, 332, 422, 995,  98], dtype=int32),
#   array([1.7881393e-07, 7.6775181e-01, 8.0697578e-01, 8.1541306e-01,
#          8.1542671e-01, 9.6278340e-01, 9.7413492e-01, 9.7430414e-01,
#          9.7742581e-01, 9.7844768e-01], dtype=float32)),
#  (array([941, 940, 938, 937, 939, 806, 807,  62, 590, 841], dtype=int32),
#   array([0.        , 0.7677518 , 0.8020142 , 0.8106823 , 0.8201458 ,
#          0.9525169 , 0.9525169 , 0.95389116, 0.9652726 , 0.97087085],
#         dtype=float32)),
#  (array([942, 886, 310, 302, 551, 626, 191, 880, 542, 122], dtype=int32),
#   array([0.        , 0.92251575, 0.9354567 , 0.9635795 , 0.9648928 ,
#          0.966048  , 0.97197986, 0.97429824, 0.9748822 , 0.9777747 ],
#         dtype=float32)),
#  (array([943, 803,  76, 218, 515, 344, 517, 584, 382, 627], dtype=int32),
#   array([5.9604645e-08, 9.2059427e-01, 9.4974256e-01, 9.5535213e-01,
#          9.5542240e-01, 9.5887625e-01, 9.5908976e-01, 9.6379024e-01,
#          9.6411657e-01, 9.6561044e-01], dtype=float32)),
#  (array([944, 711, 821, 866, 522, 742, 714, 421, 525, 549], dtype=int32),
#   array([0.        , 0.9584793 , 0.9591621 , 0.9610728 , 0.9741992 ,
#          0.97718596, 0.9776239 , 0.97958016, 0.9803032 , 0.98058873],
#         dtype=float32)),
#  (array([945, 306, 625, 859, 616, 349, 894, 825, 774, 140], dtype=int32),
#   array([0.        , 0.9582253 , 0.95873713, 0.9594583 , 0.9613427 ,
#          0.96359956, 0.9638248 , 0.9650377 , 0.9652745 , 0.96818113],
#         dtype=float32)),
#  (array([946, 636, 461, 399, 400,  61, 820, 102, 865, 306], dtype=int32),
#   array([0.        , 0.95261663, 0.95628494, 0.96367383, 0.9676299 ,
#          0.9700474 , 0.9730927 , 0.97809577, 0.9783862 , 0.978575  ],
#         dtype=float32)),
#  (array([947, 899, 711, 643, 296, 250, 604, 906, 473, 229], dtype=int32),
#   array([0.        , 0.9336301 , 0.95645577, 0.963237  , 0.96890444,
#          0.9759173 , 0.97605175, 0.97679085, 0.98029274, 0.9804234 ],
#         dtype=float32)),
#  (array([948, 395, 777, 281,   4, 146,  76, 974, 968, 898], dtype=int32),
#   array([0.        , 0.96006864, 0.97588605, 0.9778408 , 0.9782832 ,
#          0.97851515, 0.9790347 , 0.9799432 , 0.9801828 , 0.9803655 ],
#         dtype=float32)),
#  (array([949, 829, 735, 411, 322, 229, 278, 656, 260, 710], dtype=int32),
#   array([1.1920929e-07, 9.3410450e-01, 9.6763235e-01, 9.6860904e-01,
#          9.7294122e-01, 9.7672993e-01, 9.7719550e-01, 9.7754449e-01,
#          9.7837710e-01, 9.7839552e-01], dtype=float32)),
#  (array([950, 743, 535, 696, 884, 273, 379, 451, 151, 985], dtype=int32),
#   array([5.9604645e-08, 9.0794808e-01, 9.1263014e-01, 9.4976693e-01,
#          9.5081693e-01, 9.5210302e-01, 9.6134377e-01, 9.6938157e-01,
#          9.6963513e-01, 9.6999162e-01], dtype=float32)),
#  (array([951, 144, 569, 352, 199, 830, 739, 333, 122, 711], dtype=int32),
#   array([0.        , 0.9633487 , 0.96380305, 0.96386105, 0.9651466 ,
#          0.96547306, 0.9661634 , 0.9698582 , 0.97057015, 0.97071373],
#         dtype=float32)),
#  (array([952, 504, 847, 615, 241, 688, 228, 383, 558, 977], dtype=int32),
#   array([0.        , 0.9568897 , 0.965568  , 0.96869385, 0.975256  ,
#          0.9764247 , 0.9769865 , 0.9777076 , 0.97789794, 0.9784245 ],
#         dtype=float32)),
#  (array([953,  10, 645, 315, 734, 307, 657, 435, 355, 485], dtype=int32),
#   array([2.3841858e-07, 9.5922863e-01, 9.6310902e-01, 9.7074652e-01,
#          9.7663742e-01, 9.7798049e-01, 9.7854483e-01, 9.7890204e-01,
#          9.7942960e-01, 9.7991347e-01], dtype=float32)),
#  (array([954, 593, 286, 813, 664, 581, 862, 176, 320, 701], dtype=int32),
#   array([2.3841858e-07, 9.7539449e-01, 9.7637719e-01, 9.7702181e-01,
#          9.7726512e-01, 9.7731107e-01, 9.7806740e-01, 9.7934222e-01,
#          9.7942418e-01, 9.8309553e-01], dtype=float32)),
#  (array([955,  46, 396, 487, 608, 132, 394, 389, 559, 991], dtype=int32),
#   array([0.        , 0.9405166 , 0.9470812 , 0.95928335, 0.96010345,
#          0.96897936, 0.9767756 , 0.97705114, 0.978108  , 0.9788304 ],
#         dtype=float32)),
#  (array([956, 459, 854,  67, 594, 877, 777, 654, 900, 394], dtype=int32),
#   array([0.        , 0.9437566 , 0.9583449 , 0.9668025 , 0.97280586,
#          0.9728186 , 0.9732565 , 0.97773874, 0.97818404, 0.97859204],
#         dtype=float32)),
#  (array([957, 466, 119, 184, 339, 783, 973, 468, 147,  74], dtype=int32),
#   array([2.3841858e-07, 9.4613135e-01, 9.4811118e-01, 9.4913453e-01,
#          9.5401239e-01, 9.5407254e-01, 9.5613414e-01, 9.5677376e-01,
#          9.6039623e-01, 9.6339756e-01], dtype=float32)),
#  (array([958, 591, 652, 531,  68, 631, 696, 539, 806, 807], dtype=int32),
#   array([0.       , 0.9320037, 0.9584232, 0.96368  , 0.964123 , 0.9641806,
#          0.9675442, 0.9677482, 0.9714165, 0.9714165], dtype=float32)),
#  (array([959, 458, 244, 576, 896, 883, 289, 661, 871, 976], dtype=int32),
#   array([0.        , 0.97447807, 0.9745695 , 0.97560334, 0.97733575,
#          0.97992885, 0.98001003, 0.9800188 , 0.9808214 , 0.98086226],
#         dtype=float32)),
#  (array([960, 365, 693, 542, 296, 684, 552, 873, 665, 532], dtype=int32),
#   array([0.        , 0.95764893, 0.96475434, 0.96557283, 0.9706558 ,
#          0.97456604, 0.97462   , 0.975323  , 0.9762144 , 0.976634  ],
#         dtype=float32)),
#  (array([961, 984, 778, 979, 636, 761, 779,  75, 170, 222], dtype=int32),
#   array([0.        , 0.94355255, 0.9523653 , 0.9563988 , 0.96879864,
#          0.97195727, 0.97520274, 0.9753796 , 0.9757524 , 0.9777226 ],
#         dtype=float32)),
#  (array([962,  18, 607, 745, 463, 793,  17, 689, 827, 671], dtype=int32),
#   array([0.        , 0.9457438 , 0.9498334 , 0.96164   , 0.96638066,
#          0.9711949 , 0.97135234, 0.9729445 , 0.97337687, 0.974594  ],
#         dtype=float32)),
#  (array([963, 109, 351, 862, 658, 632, 872, 565, 489, 404], dtype=int32),
#   array([1.1920929e-07, 9.7075313e-01, 9.7372723e-01, 9.7470766e-01,
#          9.7702181e-01, 9.7707152e-01, 9.7763175e-01, 9.7885615e-01,
#          9.7946209e-01, 9.8027784e-01], dtype=float32)),
#  (array([964, 714, 866, 711, 220, 491, 336, 387, 991, 669], dtype=int32),
#   array([0.        , 0.91797787, 0.94044197, 0.94552875, 0.95485586,
#          0.95904714, 0.95922166, 0.96036136, 0.96443063, 0.9658758 ],
#         dtype=float32)),
#  (array([965, 516, 252, 283,  77, 462, 256,  39, 781, 253], dtype=int32),
#   array([2.3841858e-07, 9.4189739e-01, 9.5099771e-01, 9.5440412e-01,
#          9.6990108e-01, 9.7155911e-01, 9.7457469e-01, 9.7530282e-01,
#          9.7549897e-01, 9.7606575e-01], dtype=float32)),
#  (array([966, 847, 693, 506, 898, 129, 491, 884, 216, 132], dtype=int32),
#   array([2.3841858e-07, 9.6538711e-01, 9.7315645e-01, 9.7616971e-01,
#          9.7691679e-01, 9.7880101e-01, 9.8058218e-01, 9.8060358e-01,
#          9.8142272e-01, 9.8163706e-01], dtype=float32)),
#  (array([967, 717, 822, 746, 611, 398, 468, 787,  74, 633], dtype=int32),
#   array([0.        , 0.8883879 , 0.9655192 , 0.9656296 , 0.9658073 ,
#          0.9795702 , 0.9804009 , 0.9810901 , 0.98119825, 0.9831611 ],
#         dtype=float32)),
#  (array([968, 395,   4,  32, 657, 366, 782, 923, 834, 648], dtype=int32),
#   array([0.        , 0.96194947, 0.96327895, 0.9653413 , 0.9672778 ,
#          0.9708458 , 0.9728761 , 0.972885  , 0.9741421 , 0.9745798 ],
#         dtype=float32)),
#  (array([969,  91, 582, 424, 469, 164, 577, 693, 231,  72], dtype=int32),
#   array([0.        , 0.9671419 , 0.9788178 , 0.9801894 , 0.9804866 ,
#          0.98073786, 0.98144096, 0.9815922 , 0.98369503, 0.98373735],
#         dtype=float32)),
#  (array([970, 620, 137,  42,  82, 315, 817, 382, 579, 926], dtype=int32),
#   array([1.1920929e-07, 9.2127812e-01, 9.2492741e-01, 9.5049292e-01,
#          9.5394337e-01, 9.5581937e-01, 9.5772880e-01, 9.5838904e-01,
#          9.5894241e-01, 9.6117246e-01], dtype=float32)),
#  (array([971, 854, 409, 817, 226, 344, 577,   0, 129, 390], dtype=int32),
#   array([0.        , 0.9486417 , 0.9493583 , 0.9516158 , 0.9520344 ,
#          0.955842  , 0.96508473, 0.96590835, 0.96598995, 0.96926224],
#         dtype=float32)),
#  (array([972, 260, 740,  18, 300, 533, 607, 884, 384,  46], dtype=int32),
#   array([0.        , 0.9477212 , 0.9697732 , 0.97182226, 0.9744362 ,
#          0.97541666, 0.9763829 , 0.97659075, 0.97768533, 0.9792158 ],
#         dtype=float32)),
#  (array([973, 119,  73, 957, 339, 783, 468, 147, 113, 146], dtype=int32),
#   array([1.1920929e-07, 9.2849982e-01, 9.4606364e-01, 9.5613414e-01,
#          9.5806628e-01, 9.5812112e-01, 9.6058422e-01, 9.6388733e-01,
#          9.6433830e-01, 9.7242028e-01], dtype=float32)),
#  (array([974, 735, 529, 146, 948, 287, 464, 898, 122, 426], dtype=int32),
#   array([0.        , 0.96452934, 0.97756064, 0.9792796 , 0.9799432 ,
#          0.98027956, 0.98104256, 0.9810641 , 0.9813711 , 0.9816526 ],
#         dtype=float32)),
#  (array([975, 732, 993, 912, 729, 888, 600, 103, 698, 470], dtype=int32),
#   array([1.7881393e-07, 8.9345431e-01, 8.9994454e-01, 9.2652565e-01,
#          9.4603932e-01, 9.5302236e-01, 9.6851856e-01, 9.6912992e-01,
#          9.7074735e-01, 9.7382534e-01], dtype=float32)),
#  (array([976, 683, 276, 129, 797, 103, 571, 661, 817, 325], dtype=int32),
#   array([0.        , 0.9737042 , 0.97388905, 0.97590184, 0.9763192 ,
#          0.97661936, 0.9774201 , 0.9786546 , 0.97890353, 0.97903043],
#         dtype=float32)),
#  (array([977, 683, 498, 865, 415, 298, 220, 971, 985, 148], dtype=int32),
#   array([0.        , 0.96474916, 0.9655312 , 0.9684971 , 0.97027266,
#          0.9714987 , 0.9718095 , 0.9724077 , 0.97384804, 0.97385484],
#         dtype=float32)),
#  (array([978, 258, 198, 831, 991, 715, 798, 374,  82, 788], dtype=int32),
#   array([0.        , 0.9524091 , 0.9559151 , 0.9584715 , 0.97138304,
#          0.97426754, 0.9768017 , 0.9768427 , 0.9798249 , 0.9798354 ],
#         dtype=float32)),
#  (array([979, 961, 984, 636, 821, 319, 436,  86, 374, 180], dtype=int32),
#   array([2.9802322e-07, 9.5639879e-01, 9.5701015e-01, 9.6379387e-01,
#          9.7275692e-01, 9.7475612e-01, 9.7589713e-01, 9.7693056e-01,
#          9.7700423e-01, 9.8000014e-01], dtype=float32)),
#  (array([980, 979, 871, 431,  92, 231,  63,  11, 133, 469], dtype=int32),
#   array([0.        , 0.94016004, 0.96358323, 0.971405  , 0.97282034,
#          0.97474676, 0.97478825, 0.97879255, 0.97932607, 0.9805211 ],
#         dtype=float32)),
#  (array([981, 419, 347, 320,   7, 924, 882, 222, 346, 613], dtype=int32),
#   array([2.9802322e-07, 9.6615374e-01, 9.7225326e-01, 9.7807258e-01,
#          9.7821391e-01, 9.7827107e-01, 9.7869188e-01, 9.8034215e-01,
#          9.8107183e-01, 9.8117590e-01], dtype=float32)),
#  (array([982,  31, 623, 911, 517, 367, 639, 862, 951, 635], dtype=int32),
#   array([0.        , 0.9514141 , 0.9525808 , 0.95329726, 0.97102004,
#          0.9776024 , 0.9790983 , 0.9805697 , 0.9811695 , 0.98184884],
#         dtype=float32)),
#  (array([983, 172, 615, 527, 282, 233, 305, 494, 432, 726], dtype=int32),
#   array([3.5762787e-07, 9.2416018e-01, 9.3719685e-01, 9.5443118e-01,
#          9.6124506e-01, 9.7217578e-01, 9.7302216e-01, 9.7368872e-01,
#          9.7582459e-01, 9.7649974e-01], dtype=float32)),
#  (array([984,  86, 961, 814, 818, 295,  27, 979, 699, 479], dtype=int32),
#   array([1.1920929e-07, 9.2690712e-01, 9.4355255e-01, 9.4891626e-01,
#          9.5413148e-01, 9.5461142e-01, 9.5551914e-01, 9.5701015e-01,
#          9.6259433e-01, 9.6600431e-01], dtype=float32)),
#  (array([985, 986, 483, 803, 459, 517, 683, 451, 344, 343], dtype=int32),
#   array([0.        , 0.86761916, 0.9454174 , 0.9496457 , 0.95332855,
#          0.95863664, 0.9591569 , 0.95990753, 0.9610147 , 0.9626314 ],
#         dtype=float32)),
#  (array([986, 985, 798, 337, 306, 667, 728, 491, 287, 274], dtype=int32),
#   array([0.        , 0.86761916, 0.945481  , 0.9493441 , 0.9679962 ,
#          0.9746554 , 0.9759474 , 0.9773943 , 0.9778151 , 0.9796538 ],
#         dtype=float32)),
#  (array([987, 461, 675, 787, 110, 465, 865, 814, 853, 427], dtype=int32),
#   array([0.        , 0.9404354 , 0.9594869 , 0.97022617, 0.9739841 ,
#          0.97576064, 0.97668064, 0.97740924, 0.97766787, 0.9776991 ],
#         dtype=float32)),
#  (array([988, 836,  89, 227, 331, 740, 900, 538, 439, 201], dtype=int32),
#   array([0.        , 0.95838094, 0.96619445, 0.9685802 , 0.9687191 ,
#          0.9732081 , 0.9735501 , 0.97585064, 0.9777431 , 0.9782095 ],
#         dtype=float32)),
#  (array([989, 180, 581, 545, 406,  72, 861, 733, 477, 489], dtype=int32),
#   array([0.        , 0.9654732 , 0.9665283 , 0.96859956, 0.9701743 ,
#          0.97398823, 0.9745615 , 0.979559  , 0.98103374, 0.9820934 ],
#         dtype=float32)),
#  (array([990, 179, 272,  76, 565, 107, 364, 812, 614, 820], dtype=int32),
#   array([1.7881393e-07, 9.5126230e-01, 9.6974659e-01, 9.7291750e-01,
#          9.7484940e-01, 9.7867537e-01, 9.8091668e-01, 9.8134190e-01,
#          9.8190492e-01, 9.8224795e-01], dtype=float32)),
#  (array([991, 694, 741, 577, 397, 964, 858, 457, 215, 122], dtype=int32),
#   array([0.        , 0.8850238 , 0.9483818 , 0.9512546 , 0.9632936 ,
#          0.96443063, 0.96482223, 0.96543247, 0.9671319 , 0.96770287],
#         dtype=float32)),
#  (array([992, 653, 385, 182, 472, 146, 655,  69, 841, 440], dtype=int32),
#   array([0.        , 0.94934964, 0.973189  , 0.9791426 , 0.9811516 ,
#          0.9816189 , 0.9820802 , 0.9827172 , 0.98325914, 0.9837336 ],
#         dtype=float32)),
#  (array([993, 975, 174, 553, 177, 786, 737, 771,  54, 663], dtype=int32),
#   array([2.3841858e-07, 8.9994454e-01, 9.5031774e-01, 9.7030199e-01,
#          9.7386348e-01, 9.7433180e-01, 9.7498292e-01, 9.7558641e-01,
#          9.7693813e-01, 9.7784865e-01], dtype=float32)),
#  (array([994, 299, 907,  99, 304, 896, 491, 704, 259, 537], dtype=int32),
#   array([0.        , 0.94817924, 0.95795876, 0.9686762 , 0.96882695,
#          0.9697915 , 0.97280294, 0.973882  , 0.9771714 , 0.9773137 ],
#         dtype=float32)),
#  (array([995, 207, 940,  39, 877, 344, 313, 743, 710, 373], dtype=int32),
#   array([1.1920929e-07, 9.5701468e-01, 9.7742581e-01, 9.7768253e-01,
#          9.7821993e-01, 9.7826695e-01, 9.7850633e-01, 9.7933847e-01,
#          9.7954184e-01, 9.7976238e-01], dtype=float32)),
#  (array([996, 619, 171, 225, 497, 453, 905, 746, 611, 319], dtype=int32),
#   array([1.7881393e-07, 9.7567743e-01, 9.7567862e-01, 9.7604203e-01,
#          9.7773832e-01, 9.7895890e-01, 9.7899163e-01, 9.8079550e-01,
#          9.8089480e-01, 9.8125857e-01], dtype=float32)),
#  (array([997, 757,  15, 248, 308,  75, 604, 968, 527, 740], dtype=int32),
#   array([0.        , 0.9423567 , 0.96082056, 0.962641  , 0.9704774 ,
#          0.9767007 , 0.97832066, 0.9797346 , 0.98055613, 0.98207325],
#         dtype=float32)),
#  (array([998, 178, 290, 476, 598, 503, 488, 716, 173, 264], dtype=int32),
#   array([0.        , 0.9485828 , 0.9624341 , 0.96910053, 0.9780795 ,
#          0.98086005, 0.9831025 , 0.98333293, 0.98337203, 0.9836811 ],
#         dtype=float32)),
#  (array([999, 552, 907, 102, 847, 458, 112, 723, 302, 161], dtype=int32),
#   array([0.        , 0.9460272 , 0.9616492 , 0.96497047, 0.97138315,
#          0.9738178 , 0.9738442 , 0.9767074 , 0.9769937 , 0.97855496],
#         dtype=float32))]
